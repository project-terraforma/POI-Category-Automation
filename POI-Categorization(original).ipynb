# %%
# %pip install overturemaps lonboard geopandas shapely
# %pip install google.generativeai
# Out:
# Requirement already satisfied: overturemaps in c:\users\chaav\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: lonboard in c:\users\chaav\anaconda3\lib\site-packages (0.10.4)
# Requirement already satisfied: geopandas in c:\users\chaav\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: shapely in c:\users\chaav\anaconda3\lib\site-packages (2.1.0)
# Requirement already satisfied: click>=8.1.7 in c:\users\chaav\anaconda3\lib\site-packages (from overturemaps) (8.1.7)
# Requirement already satisfied: numpy>=1.26.4 in c:\users\chaav\anaconda3\lib\site-packages (from overturemaps) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.2 in c:\users\chaav\anaconda3\lib\site-packages (from overturemaps) (16.1.0)
# Requirement already satisfied: anywidget<0.10.0,>=0.9.0 in c:\users\chaav\anaconda3\lib\site-packages (from lonboard) (0.9.18)
# Requirement already satisfied: arro3-compute>=0.4.1 in c:\users\chaav\anaconda3\lib\site-packages (from lonboard) (0.4.6)
# Requirement already satisfied: arro3-core>=0.4.1 in c:\users\chaav\anaconda3\lib\site-packages (from lonboard) (0.4.6)
# Requirement already satisfied: arro3-io>=0.4.1 in c:\users\chaav\anaconda3\lib\site-packages (from lonboard) (0.4.6)
# Requirement already satisfied: ipywidgets>=7.6.0 in c:\users\chaav\anaconda3\lib\site-packages (from lonboard) (7.8.1)
# Requirement already satisfied: pyproj>=3.3 in c:\users\chaav\anaconda3\lib\site-packages (from lonboard) (3.7.1)
# Requirement already satisfied: traitlets>=5.7.1 in c:\users\chaav\anaconda3\lib\site-packages (from lonboard) (5.14.3)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\chaav\anaconda3\lib\site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in c:\users\chaav\anaconda3\lib\site-packages (from geopandas) (24.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\chaav\anaconda3\lib\site-packages (from geopandas) (2.2.2)
# Requirement already satisfied: psygnal>=0.8.1 in c:\users\chaav\anaconda3\lib\site-packages (from anywidget<0.10.0,>=0.9.0->lonboard) (0.12.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\chaav\anaconda3\lib\site-packages (from anywidget<0.10.0,>=0.9.0->lonboard) (4.11.0)
# Requirement already satisfied: colorama in c:\users\chaav\anaconda3\lib\site-packages (from click>=8.1.7->overturemaps) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\chaav\anaconda3\lib\site-packages (from ipywidgets>=7.6.0->lonboard) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\chaav\anaconda3\lib\site-packages (from ipywidgets>=7.6.0->lonboard) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\chaav\anaconda3\lib\site-packages (from ipywidgets>=7.6.0->lonboard) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\chaav\anaconda3\lib\site-packages (from ipywidgets>=7.6.0->lonboard) (8.27.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\chaav\anaconda3\lib\site-packages (from ipywidgets>=7.6.0->lonboard) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\chaav\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chaav\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\chaav\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: certifi in c:\users\chaav\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2024.12.14)
# Requirement already satisfied: decorator in c:\users\chaav\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->lonboard) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\chaav\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->lonboard) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\chaav\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->lonboard) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\chaav\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->lonboard) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\chaav\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->lonboard) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\chaav\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->lonboard) (0.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\chaav\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\chaav\anaconda3\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (7.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\chaav\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.6.0->lonboard) (0.8.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\chaav\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\chaav\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\chaav\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\chaav\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\chaav\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (6.4.1)
# Requirement already satisfied: wcwidth in c:\users\chaav\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets>=7.6.0->lonboard) (0.2.5)
# Requirement already satisfied: executing in c:\users\chaav\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.6.0->lonboard) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\chaav\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.6.0->lonboard) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\chaav\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.6.0->lonboard) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\chaav\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\chaav\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\chaav\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\chaav\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (2.2.0)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\chaav\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (75.1.0)
# Requirement already satisfied: babel>=2.10 in c:\users\chaav\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\chaav\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\chaav\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\chaav\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\chaav\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\chaav\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\chaav\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (21.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\chaav\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\chaav\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\chaav\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (1.6.7)
# Requirement already satisfied: nest-asyncio in c:\users\chaav\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (1.6.0)
# Requirement already satisfied: psutil in c:\users\chaav\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (5.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\chaav\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\chaav\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\chaav\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\chaav\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\chaav\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (305.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\chaav\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\chaav\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\chaav\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\chaav\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\chaav\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\chaav\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\chaav\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\chaav\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\chaav\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (1.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\chaav\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chaav\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chaav\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (2.2.3)
# Requirement already satisfied: webencodings in c:\users\chaav\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\chaav\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\chaav\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\chaav\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (2.1)
# Requirement already satisfied: uri-template in c:\users\chaav\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\chaav\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\chaav\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\chaav\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (2.5)
# Requirement already satisfied: pycparser in c:\users\chaav\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\chaav\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.6.0->lonboard) (1.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google.generativeai in c:\users\chaav\anaconda3\lib\site-packages (0.8.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\chaav\anaconda3\lib\site-packages (from google.generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\chaav\anaconda3\lib\site-packages (from google.generativeai) (2.24.2)
# Requirement already satisfied: google-api-python-client in c:\users\chaav\anaconda3\lib\site-packages (from google.generativeai) (2.169.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\chaav\anaconda3\lib\site-packages (from google.generativeai) (2.39.0)
# Requirement already satisfied: protobuf in c:\users\chaav\anaconda3\lib\site-packages (from google.generativeai) (5.29.4)
# Requirement already satisfied: pydantic in c:\users\chaav\anaconda3\lib\site-packages (from google.generativeai) (2.8.2)
# Requirement already satisfied: tqdm in c:\users\chaav\anaconda3\lib\site-packages (from google.generativeai) (4.66.5)
# Requirement already satisfied: typing-extensions in c:\users\chaav\anaconda3\lib\site-packages (from google.generativeai) (4.11.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\chaav\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google.generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\chaav\anaconda3\lib\site-packages (from google-api-core->google.generativeai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\chaav\anaconda3\lib\site-packages (from google-api-core->google.generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\chaav\anaconda3\lib\site-packages (from google-auth>=2.15.0->google.generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\chaav\anaconda3\lib\site-packages (from google-auth>=2.15.0->google.generativeai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\chaav\anaconda3\lib\site-packages (from google-auth>=2.15.0->google.generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\chaav\anaconda3\lib\site-packages (from google-api-python-client->google.generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\chaav\anaconda3\lib\site-packages (from google-api-python-client->google.generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\chaav\anaconda3\lib\site-packages (from google-api-python-client->google.generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\chaav\anaconda3\lib\site-packages (from pydantic->google.generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\chaav\anaconda3\lib\site-packages (from pydantic->google.generativeai) (2.20.1)
# Requirement already satisfied: colorama in c:\users\chaav\anaconda3\lib\site-packages (from tqdm->google.generativeai) (0.4.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\chaav\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google.generativeai) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\chaav\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google.generativeai) (1.71.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\chaav\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google.generativeai) (3.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\chaav\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google.generativeai) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chaav\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google.generativeai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chaav\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google.generativeai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chaav\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google.generativeai) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chaav\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google.generativeai) (2024.12.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %cd Helper-functions
# %run category-tree.py
# %cd ..
# Out:
# c:\Users\chaav\OneDrive\Documents\GitHub\POI-Category-Automation\Helper-functions
# Wrote category_tree.json with 22 top-level entries.
# c:\Users\chaav\OneDrive\Documents\GitHub\POI-Category-Automation

# %%
import overturemaps as om
from overturemaps import core
import overturemaps
import pandas
import geopandas as gpd
from shapely import wkb
from lonboard import Map, PolygonLayer, ScatterplotLayer
import ipywidgets as widgets
import numpy as np
from IPython.display import display
import json
import requests
from bs4 import BeautifulSoup
import time
import concurrent.futures
import tqdm

# %%
with open('Data/category_tree.json', 'r') as f:
    category_tree = json.load(f)

# %%
def create_map(dataset):
    layer = ScatterplotLayer.from_geopandas(
        dataset,
        get_fill_color=[255, 0, 0],
        radius_min_pixels=5,
    )

    view_state = {
        "longitude": (bbox[0] + bbox[2]) / 2,
        "latitude": (bbox[1] + bbox[3]) / 2,
        "zoom": 8,
        "pitch": 45,
    }
    m = Map(layer, view_state=view_state)
    return m

# %%
def get_most_detailed_category(current_category, poi_metadata, tree):
    # Base Case: No further sub-categories
    if current_category not in tree or not tree[current_category]:
        return current_category  

    sub_categories = tree[current_category]

    # Example Matching Logic: Keyword search in POI name/description
    for sub_cat in sub_categories:
        if sub_cat.replace('-', ' ') in poi_metadata.lower():
            return get_most_detailed_category(sub_cat, poi_metadata, tree)

    # If no match found, return current category
    return current_category

# %%
def get_first_website(websites_list):
    if websites_list and isinstance(websites_list, list) and len(websites_list) > 0 and websites_list[0] and isinstance(websites_list[0], str):
        return websites_list[0]
    return ""

# %%
def scrape_website(url, timeout = 5):
    try:
        response = requests.get(url, timeout=timeout)
        response.raise_for_status()  # Raise an error for bad responses
        soup = BeautifulSoup(response.text, 'html.parser')

        title = soup.title.string if soup.title else 'No title found'
        meta_desc =  ""
        meta_tag = soup.find('meta', attrs={'name': 'description'})
        if meta_tag:
            meta_desc = meta_tag.get('content', '')

        h1_tag = [tag.get_text(strip=True) for tag in soup.find_all('h1')]

        screaped_text = f"Title: {title}. Meta Description: {meta_desc}. Heading: {';'.join(h1_tag)}"

        return screaped_text
    
    except Exception as e:
        print(f"Failed to Scrape: {url}: {e}")
        return ""

# %%
# specify bounding box
bbox = 9.0894, 45.5042, 9.1094, 45.5172

# %%
place_dataset = core.geodataframe("place", bbox=bbox)
print(place_dataset.shape)
# Out:
# (251, 15)

# %%
# Read the categories.txt file
with open('Data/categories.txt', 'r') as file:
    categories_data = file.readlines()
categories_data = categories_data[1:]

# Split the data by semicolons and extract the part before the semi-colon
categories_list = [entry.split(';')[0] for entry in categories_data]

# %%
# Pulling out the places and websites
websites = {}
number = 0
for i in range(len(place_dataset.id)):
    # print(f"Place: {place_dataset.names[i]['primary']}")
    number += 1
    websites[place_dataset.names[i]['primary']] = place_dataset.websites[i]

# Save all websites as a comma-separated string
websites_str = " , ".join(
    site[0] if site is not None and len(site) > 0 else "No website Found"
    for site in websites.values()
)

# Test Features

# print(websites_str)
print(number)
# Out:
# 251

# %%
# Pulling out the places' social media links
socials_dict = {}
for i in range(len(place_dataset.id)):
    place_name = place_dataset.names[i]['primary']
    # Assuming place_dataset.socials[i] contains the social media information
    # This might be a list of strings, a dictionary, or None
    social_links = place_dataset.socials[i]
    socials_dict[place_name] = social_links

# Print the extracted social media links
# print(socials_dict) 

# Example: Print socials for the first few places to check the structure
# count = 0
# for place, links in socials_dict.items():
#     if count < 5: # Print for the first 5 places
#         print(f"Place: {place}, Socials: {links}")
#         count += 1
#     else:
#         break

# If you want a string representation similar to websites_str:
# This part depends heavily on the actual structure of place_dataset.socials[i]
# Assuming it's a list of strings (URLs) or can be easily converted to a string:
socials_str_list = []
for place_name, social_links_list in socials_dict.items():
    if social_links_list:
        # If social_links_list is a list of strings:
        if isinstance(social_links_list, list) and all(isinstance(link, str) for link in social_links_list):
            links_str = ", ".join(social_links_list)
        # If social_links_list is a dictionary (e.g., {'facebook': 'url', 'instagram': 'url'}):
        elif isinstance(social_links_list, dict):
            links_str = ", ".join([f"{platform}: {url}" for platform, url in social_links_list.items()])
        # Add more conditions if other structures are possible or convert to string directly
        else:
            links_str = str(social_links_list) # Fallback to string conversion
        socials_str_list.append(f"{place_name}: [{links_str}]")
    else:
        socials_str_list.append(f"{place_name}: No socials found")

# print("\nFormatted Socials String:")
for item in socials_str_list[:14]: # Print for the first 5 places
    print(item)
# Out:
# Parco Nicolas: [['https://www.facebook.com/110607897987764']]
# Edimol Sas: [['https://www.facebook.com/693284050783126']]
# Casual Store money transfer: [['https://www.facebook.com/132504977165630']]
# Molino Dorino: [['https://www.facebook.com/451512508382062']]
# Atlassib: [['https://www.facebook.com/305979330228103']]
# CSC - Casa salvadorena Cultural: [['https://www.facebook.com/1484762838421631']]
# Prodent Italia: [['https://www.facebook.com/1346616508739611']]
# Saldoplast: [['https://www.facebook.com/203914236705564']]
# Swiss DolorClast Italia: [['https://www.facebook.com/378005672556733']]
# Mud Museum - Open Space: [['https://www.facebook.com/171269036417134']]
# PR No Ordinary Training Studio: [['https://www.facebook.com/479433592451814']]
# Multiprint: [['https://www.facebook.com/1670753372951449']]
# LR Health & Beauty Italia: [['https://www.facebook.com/147643092068177']]
# Team Russo: [['https://www.facebook.com/102509945702311']]

# %%
scraped_socials_content = {}
tasks_for_social_scraping = []

# Prepare tasks for scraping
for place_name, social_links_list in socials_dict.items():
    if social_links_list is not None:
        # Ensure social_links_list is iterable (e.g., numpy array or list)
        if isinstance(social_links_list, (list, np.ndarray)):
            for social_url in social_links_list:
                if isinstance(social_url, str) and social_url.startswith(('http://', 'https://')):
                    tasks_for_social_scraping.append((place_name, social_url))
        elif isinstance(social_links_list, str) and social_links_list.startswith(('http://', 'https://')): # Handle case where it might be a single string
            tasks_for_social_scraping.append((place_name, social_links_list))


total_social_urls = len(tasks_for_social_scraping)
scraped_social_urls_count = 0
progress_step_social = max(1, total_social_urls // 20) if total_social_urls > 0 else 1

def scrape_social_url_wrapper(args):
    global scraped_social_urls_count
    place_name, url = args
    scraped_content = scrape_website(url) # Using the existing scrape_website function
    
    # Increment and print progress
    scraped_social_urls_count += 1
    if total_social_urls > 0 and (scraped_social_urls_count % progress_step_social == 0 or scraped_social_urls_count == total_social_urls):
        percent = (scraped_social_urls_count / total_social_urls) * 100
        print(f"Scraped {scraped_social_urls_count}/{total_social_urls} ({percent:.1f}%) social URLs.")
        
    return place_name, url, scraped_content if scraped_content else "Scraping Failed or No Content"

print(f"Found {total_social_urls} social URLs to scrape.")

# Use ThreadPoolExecutor for concurrent scraping
with concurrent.futures.ThreadPoolExecutor(max_workers=3000) as executor: # Adjusted max_workers for social media sites
    social_results = list(executor.map(scrape_social_url_wrapper, tasks_for_social_scraping))

# Store the results
for place_name, url, content in social_results:
    if place_name not in scraped_socials_content:
        scraped_socials_content[place_name] = []
    scraped_socials_content[place_name].append({url: content})

print("\nScraping of social URLs complete.")
print("Scraped Social Media Content:")
# Print the scraped social media content (first few for brevity)
count_printed = 0
for place, contents in scraped_socials_content.items():
    if count_printed < 10: # Limit printing for brevity
        print(f"\nPlace: {place}")
        for content_dict in contents:
            for url_key, text_content in content_dict.items():
                print(f"  URL: {url_key}")
                print(f"  Content: {text_content[:200]}...") # Print first 200 chars
        count_printed +=1
    else:
        print(f"\n... and {len(scraped_socials_content) - count_printed} more places.")
        break
        
if not scraped_socials_content:
    print("No social media content was scraped.")

# New section to print results in the requested format
print("\n--- Formatted Scraped Socials Information (Name: Scraped Content from Socials) ---")
formatted_social_info_output_list = []

if isinstance(scraped_socials_content, dict):
    for place_name_key, list_of_content_dicts in scraped_socials_content.items():
        # list_of_content_dicts is a list of dicts, e.g., [{'url1': 'scraped_text1'}, {'url2': 'scraped_text2'}]
        
        all_scraped_texts_for_this_place = []
        for single_url_content_dict in list_of_content_dicts:
            # single_url_content_dict is e.g., {'url1': 'scraped_text1'}
            # We need the values (the scraped text strings)
            for scraped_text_item in single_url_content_dict.values():
                if scraped_text_item and isinstance(scraped_text_item, str): # Ensure it's a non-empty string
                    all_scraped_texts_for_this_place.append(scraped_text_item)
        
        # Concatenate all scraped texts for this place, separated by " | "
        # This aggregated_social_info is the "socials-scraped-Information"
        aggregated_social_info = " | ".join(all_scraped_texts_for_this_place)
        
        # Escape double quotes in place_name_key and aggregated_social_info to ensure valid string literals in the output
        place_name_escaped = str(place_name_key).replace('"', '\\"')
        aggregated_social_info_escaped = aggregated_social_info.replace('"', '\\"')
        
        formatted_line = f'"{place_name_escaped}": "{aggregated_social_info_escaped}"'
        print(formatted_line)
        formatted_social_info_output_list.append(formatted_line)

    if not formatted_social_info_output_list:
        print("No social media content was available in scraped_socials_content to format.")
else:
    print("Variable 'scraped_socials_content' is not a dictionary. Cannot produce formatted social info.")
# Out:
# Found 185 social URLs to scrape.
# Scraped 9/185 (4.9%) social URLs.
# Scraped 18/185 (9.7%) social URLs.
# Scraped 27/185 (14.6%) social URLs.
# Scraped 36/185 (19.5%) social URLs.
# Scraped 45/185 (24.3%) social URLs.
# Scraped 54/185 (29.2%) social URLs.
# Scraped 63/185 (34.1%) social URLs.
# Scraped 72/185 (38.9%) social URLs.
# Scraped 81/185 (43.8%) social URLs.
# Scraped 90/185 (48.6%) social URLs.
# Scraped 99/185 (53.5%) social URLs.
# Scraped 108/185 (58.4%) social URLs.
# Scraped 117/185 (63.2%) social URLs.
# Scraped 126/185 (68.1%) social URLs.
# Scraped 135/185 (73.0%) social URLs.
# Scraped 144/185 (77.8%) social URLs.
# Scraped 153/185 (82.7%) social URLs.
# Scraped 162/185 (87.6%) social URLs.
# Scraped 171/185 (92.4%) social URLs.
# Scraped 180/185 (97.3%) social URLs.
# Scraped 185/185 (100.0%) social URLs.
#
# Scraping of social URLs complete.
# Scraped Social Media Content:
#
# Place: Parco Nicolas
#   URL: https://www.facebook.com/110607897987764
#   Content: Title: Parco del Castello di Verde. Meta Description: . Heading: ...
#
# Place: Edimol Sas
#   URL: https://www.facebook.com/693284050783126
#   Content: Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ...
#
# Place: Casual Store money transfer
#   URL: https://www.facebook.com/132504977165630
#   Content: Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ...
#
# Place: Molino Dorino
#   URL: https://www.facebook.com/451512508382062
#   Content: Title: Molino Dorino. Meta Description: . Heading: ...
#
# Place: Atlassib
#   URL: https://www.facebook.com/305979330228103
#   Content: Title: Atlassib. Meta Description: . Heading: ...
#
# Place: CSC - Casa salvadorena Cultural
#   URL: https://www.facebook.com/1484762838421631
#   Content: Title: CSC - Casa salvadorena Cultural | Milan . Meta Description: CSC - Casa salvadorena Cultural, Milano. 626 likes · 33 were here. PARA NUSTRA JUVENTUD ITALO-SALVADORENA. NACE ESTE BONITO PROYECTO ...
#
# Place: Prodent Italia
#   URL: https://www.facebook.com/1346616508739611
#   Content: Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ...
#
# Place: Saldoplast
#   URL: https://www.facebook.com/203914236705564
#   Content: Title: Saldoplast SRL | Pero . Meta Description: Saldoplast SRL, Pero, Italy. 53 likes. AZIENDA LEADER NELLA PRODUZIONE DI SACCHI SOTTOVUOTO/SALVASPAZIO CON VALVOLA , DOYPACK E SACCHI PER USO COSMETIC...
#
# Place: Swiss DolorClast Italia
#   URL: https://www.facebook.com/378005672556733
#   Content: Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ...
#
# Place: Mud Museum - Open Space
#   URL: https://www.facebook.com/171269036417134
#   Content: Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ...
#
# ... and 175 more places.
#
# --- Formatted Scraped Socials Information (Name: Scraped Content from Socials) ---
# "Parco Nicolas": "Title: Parco del Castello di Verde. Meta Description: . Heading: "
# "Edimol Sas": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Casual Store money transfer": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Molino Dorino": "Title: Molino Dorino. Meta Description: . Heading: "
# "Atlassib": "Title: Atlassib. Meta Description: . Heading: "
# "CSC - Casa salvadorena Cultural": "Title: CSC - Casa salvadorena Cultural | Milan . Meta Description: CSC - Casa salvadorena Cultural, Milano. 626 likes · 33 were here. PARA NUSTRA JUVENTUD ITALO-SALVADORENA. NACE ESTE BONITO PROYECTO DE INTEGRACION DE.... Heading: "
# "Prodent Italia": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Saldoplast": "Title: Saldoplast SRL | Pero . Meta Description: Saldoplast SRL, Pero, Italy. 53 likes. AZIENDA LEADER NELLA PRODUZIONE DI SACCHI SOTTOVUOTO/SALVASPAZIO CON VALVOLA , DOYPACK E SACCHI PER USO COSMETICO.... Heading: "
# "Swiss DolorClast Italia": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Mud Museum - Open Space": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "PR No Ordinary Training Studio": "Title: PR No Ordinary Training | Pero . Meta Description: PR No Ordinary Training, Pero. 159 likes. Personal Coach. Heading: "
# "Multiprint": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
#
# "Blustar Car": "Title: Mercedesbenz Blustar Car Srl | Milan . Meta Description: Mercedesbenz Blustar Car Srl, Milan, Italy. 50 likes · 16 were here. Benvenuti nella pagina Facebook di Mercedesbenz Blustar Car Srl.info@blustarcar.it,.... Heading: "
# "Mercedes-Benz Service": "Title: Mercedes-Benz Service | Milan . Meta Description: Mercedes-Benz Service, Milan, Italy. 9 likes · 25 were here. Officina autorizzata Mercedes-Benz specializzata in assistenza, manutenzione ordinaria,.... Heading: "
# "Pizza e Brace": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Milly bar": "Title: Milly bar | Pero . Meta Description: Milly bar, Pero, Italy. 319 likes · 47 were here. tavola fredda. Heading: "
# "Autostradale": "Title: Deposito Autostradale. Meta Description: . Heading: "
# "X-Moto": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "MABA Shopping Pero": "Title: MABA Shopping Pero | Pero . Meta Description: MABA Shopping Pero, Pero. 294 likes · 1 was here. Gestito 9 anni con un altro nome, al decimo anno abbiamo aperto il nostro format. Siamo sempre noi. Heading: "
# "Safetykleen Italia - Soluzioni complete per il lavaggio pezzi": "Title: Safetykleen Italia - Soluzioni complete per il lavaggio pezzi | Pero . Meta Description: Safetykleen Italia - Soluzioni complete per il lavaggio pezzi, Pero. 4 likes · 1 talking about this. Safetykleen è leader mondiale nella fornitura di.... Heading: "
# "Dott.ssa Simona Adelaide Martini Psicologa-Psicoterapeuta Emdr": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Matcro Lab di Dott. Mattia Crosta": "Title: Matcro_lab. Meta Description: . Heading: "
# "Speedy Car Snc": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Cogepro Business Center": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Motormobile Rovida": "Title: Motormobile rovida | Pero . Meta Description: Motormobile rovida, Pero, Italy. 177 likes · 2 were here. Motormobile Rovida
# Servizio di riparazione autoveicoli, tagliandi certificati, diagnosi.... Heading: "
# "Villamark Marcatura - Villa Luigi & Figlio Srl": "Title: Villamark Marcatura - Villa Luigi & Figlio Srl | Pero . Meta Description: Villamark Marcatura - Villa Luigi & Figlio Srl, Pero, Italy. 107 likes · 1 was here. Vendita timbri, consulenza per marcare: fornitura servizi per.... Heading: "
# "Usatokay - Mercatino dell'Usato": "Title: Usatokay | Pero . Meta Description: Usatokay, Pero, Lombardia. 588 likes · 1 was here. 🛒 Compriamo Oggetti  Vintage&Design
# 👜 Vendiamo Oggetti e Abbigliamento 📺
# STIAMO LAVORANDO PER CERCARE.... Heading: "
# "Timberland": "Title: Timberland | Pero . Meta Description: Timberland, Pero, Italy. 130 likes · 48 were here. Fashion Designer. Heading: "
# "DACAN": "Title: DACAN | Pero . Meta Description: DACAN, Pero. 677 likes · 4 talking about this · 327 were here. . Heading: "
# "Gramsci Car Center S.r.l": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Action Shooting Italia": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Bolliger Moving": "Title: Bolliger SpA | Pero . Meta Description: Bolliger SpA, Pero. 18 likes · 1 talking about this. Traslochi nazionali, internazionali e industriali.
# Fine art e Relocation.. Heading: "
# "Easy&Fast": "Title: Easy&Fast | Pero . Meta Description: Easy&Fast, Pero, Lombardia. 52 likes. Siamo una giovane realtà logistica specializzata nella consegna multigiornaliera.. Heading: "
# "Santoemma Srl": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Termostahl srl - tempra per induzione": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "G.T.R. Car Service": "Title: Gtr Car Service. Meta Description: . Heading: "
# "Deltacon Ricerca e Sviluppo": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Evoluzione Parrucchieri": "Title: Evoluzione Parrucchieri. Meta Description: . Heading: "
# "Urban Wall - Milano Climbing Factory": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Impresa Montali srl": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "SGS Comunicazione": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Milano Sign": "Title: Milano Sign | Pero . Meta Description: Milano Sign, Pero, Italy. 61 likes · 2 were here. Siamo una giovane nuova azienda costituita 2015 basata sull'esperienza
# di operatori nel settore di più.... Heading: "
# "Route 41": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "DSS Trasporti Bio Pharma Solution": "Title: DSS Bio Pharma Solution | Pero . Meta Description: DSS Bio Pharma Solution, Pero, Italy. 131 likes. Trasporti dedicati, specializzati nella temperatura controllata 🌡❄️. Heading: "
# "Flavourland srl": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "The Loft Milano Villapizzone": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "StoryTime - Lombardia": "Title: Stotytime_gc | Pero . Meta Description: Stotytime_gc, Pero, Italy. 52 likes · 2 talking about this. Aiuto imprenditori, blogger, artigiani, professionisti.... lomabrdi a farsi conoscere meglio.... Heading: "
# "Rhiag Group": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Vimercati S.p.A.": "Title: Vimercati S.p.a.. Meta Description: . Heading: "
# "Consorzio Insiamo": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "The Gate": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Europatarghe srl": "Title: Europatarghe srl | Pero . Meta Description: Europatarghe srl, Pero, Italy. 195 likes. produzione targhe. Heading: "
# "Matiba digital marketing": "Title: Facebook. Meta Description: . Heading: "
# "Detente et Beaute": "Title: Détente et Beauté | Pero . Meta Description: Détente et Beauté, Pero, Italy. 4 likes · 1 was here. Health/beauty. Heading: "
# "Distilleria Artigianale Milano": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "SAMA di Massimo Santacaterina": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Bar Bijou Caffetteria": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Presspoint": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Saltafoss": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Dubini Traslochi E Servizi Srl": "Title: Dubini Traslochi E Servizi Srl | Pero . Meta Description: Dubini Traslochi E Servizi Srl, Pero. 6 likes. Local business. Heading: "
# "Mahamevnawa Buddhist Meditation Monastery": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Parrocchia San Leonardo": "Title: Parrocchia San Leonardo. Meta Description: . Heading: "
# "Gruppo Sirio": "Title: Gruppo Sirio Associazione d'Arte | Milan . Meta Description: Gruppo Sirio Associazione d'Arte, Milano. 122 likes · 1 talking about this. Post di incontri, mostre, conferenze , laboratori artistici promossi da.... Heading: "
# "Circolo Fotografico Trevisani": "Title: Circolo Fotografico Trevisani | Milan . Meta Description: Circolo Fotografico Trevisani, Milan, Italy. 430 likes · 19 talking about this · 5 were here. Il circolo è aperto ogni giovedì dalle 21.. Heading: "
# "Circolo SEL - E. Ragionieri": "Title: Circolo Sel Zona 8 - E. Ragionieri | Milan . Meta Description: Circolo Sel Zona 8 - E. Ragionieri, Milan, Italy. 16 likes · 61 were here. Political Organization. Heading: "
# "ASD Zonaotto": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Balzoo - Banco Italiano Zoologico APS": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Faridamore": "Title: Farida More Impresa Di Pulizie | Milan . Meta Description: Farida More Impresa Di Pulizie, Milan, Italy. 110 likes. impresa di pulizie e servizi vari per condomini, aziende e privati, ristrutturazioni edili,, imbianc. Heading: "
# "Skilifting & Bike": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Leone": "Title: Oil One. Meta Description: . Heading: "
# "Bar fratelli Guido": "Title: Fratelli Guido. Meta Description: . Heading: "
# "La Pergola": "Title: Milano Ristorante La Pergola. Meta Description: . Heading: "
# "Trattoria Italo Cinese": "Title: Trattoria Italo-cinese. Meta Description: . Heading: "
# "Autolavaggio SM2": "Title: Autolavaggio SM2. Meta Description: . Heading: "
# "Joe Eze Foundation": "Title: Joeeze foundation  | Milano Marittima . Meta Description: Joeeze foundation , Milano Marittima, Emilia-Romagna, Italy. 2 likes. Joe Eze foundation is a non governmental organisation. Heading: "
# "SisalPay": "Title: SisalPay | Milan . Meta Description: SisalPay, Milan, Italy. Financial service. Heading: "
# "Bardelli Taglio Laser": "Title: Bardelli Taglio Laser | Milan . Meta Description: Bardelli Taglio Laser, Milan, Italy. 175 likes. Plexiglas- taglio laser- fustelle americane
# Cartotecnica,serigrafia e lavorazione di ogni tipo.. Heading: "
# "Kebap House": "Title: Kebap house. Meta Description: . Heading: "
# "Vita Studio": "Title: Vita Studio. Meta Description: . Heading: "
# "Vetrofanie Milano sas di Pulici Paolo": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Strane Officine": "Title: Strane Officine. Meta Description: . Heading: "
# "Non Solo Cross": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Autoclub S.N.C.": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Lucia Pascale eco designer": "Title: Lucia Pascale | Milan . Meta Description: Lucia Pascale, Milan, Italy. 313 likes. Stampo a mano foglie, fiori, radici, su tessuti naturali. Per appuntamento: 349 8410392. Heading: "
# "ODStore": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Gruppo Grancasa": "Title: Gruppo Grancasa | Pero . Meta Description: Gruppo Grancasa, Pero, Italy. 176 likes · 44 were here. Retail company. Heading: "
# "Ristorante La Rosa Incantata": "Title: Ristorante La Rosa Incantata | Pero . Meta Description: Ristorante La Rosa Incantata, Pero. 3 likes. Ristorante ispirato alla Bella e La Bestia �. Menu’ carne e pesce, griglia a vista ��. Heading: "
# "La Rosa incantata": "Title: La Rosa Incantata Bistrot  | Pero . Meta Description: La Rosa Incantata Bistrot , Pero. 5 likes. Restaurant. Heading: "
# "Grancasa": "Title: Grancasa Pero. Meta Description: . Heading: "
# "Tecnomat": "Title: Tecnomat. Meta Description: Tecnomat. 317 likes · 301 were here. Tutto per costruire, ristrutturare e fare manutenzione.. Heading: "
# "Bricoman": "Title: Bricoman | Milan . Meta Description: Bricoman, Milan, Italy. 16 were here. 0001. Heading: "
# "MAGIA Coiffeur by Lella": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Coiffeur Pour Dame Di Attanasio Graziella": "Title: Coiffeur pour dame magia milano | Milan . Meta Description: Coiffeur pour dame magia milano, Milan, Italy. 25 likes · 73 were here. Hair Salon. Heading: "
# "Restaurant One": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Due Bacchette": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Cinque Stelle": "Title: Ristorante 5 Stelle. Meta Description: . Heading: "
# "TESL": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "La Moderna s.r.l": "Title: La Moderna s.r.l | Pero . Meta Description: La Moderna s.r.l, Pero, Italy. 152 likes · 8 were here. Automotive Body Shop. Heading: "
# "Hamerica’s Cascina merlata bloom ": "Title: Hamerica’s Cascina merlata bloom  | Milan . Meta Description: Hamerica’s Cascina merlata bloom , Milano, Lombardia. 11 likes · 24 were here. Ristorante di cucina americana. Heading: "
# "Excélsa Italia": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "
"Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Salmoiraghi & Viganò": "Title: Salmoiraghi & Viganò | Milan . Meta Description: Salmoiraghi & Viganò, Milan. La più importante catena di ottica in Italia con la migliore offerta di occhiali da vista, occhiali da sole e lenti a contatto.. Heading: "
# "Calvin Klein Jeans": "Title: Calvin Klein Jeans | Milan . Meta Description: Calvin Klein Jeans, Milan. Modern. Sensual. Iconic. Calvin Klein delivers effortlessly minimal underwear and denim for every day. Designed for everybody,.... Heading: "
# "Thun Shop Milano Merlata": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: "
# "Deposito Ferroviario di Milano Fiorenza": "Title: Deposito Ferroviario di Milano Fiorenza. Meta Description: . Heading: "
# "Open Air Theatre San Carlo": "Title: Open Air Theatre San Carlo. Meta Description: . Heading: "

# %%
# Join the list of formatted social info strings into a single comma-separated string
scraped_socials_string = ", ".join(formatted_social_info_output_list)
print(scraped_socials_string)
# Out:
# "Parco Nicolas": "Title: Parco del Castello di Verde. Meta Description: . Heading: ", "Edimol Sas": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "Casual Store money transfer": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "Molino Dorino": "Title: Molino Dorino. Meta Description: . Heading: ", "Atlassib": "Title: Atlassib. Meta Description: . Heading: ", "CSC - Casa salvadorena Cultural": "Title: CSC - Casa salvadorena Cultural | Milan . Meta Description: CSC - Casa salvadorena Cultural, Milano. 626 likes · 33 were here. PARA NUSTRA JUVENTUD ITALO-SALVADORENA. NACE ESTE BONITO PROYECTO DE INTEGRACION DE.... Heading: ", "Prodent Italia": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "Saldoplast": "Title: Saldoplast SRL | Pero . Meta Description: Saldoplast SRL, Pero, Italy. 53 likes. AZIENDA LEADER NELLA PRODUZIONE DI SACCHI SOTTOVUOTO/SALVASPAZIO CON VALVOLA , DOYPACK E SACCHI PER USO COSMETICO.... Heading: ", "Swiss DolorClast Italia": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "Mud Museum - Open Space": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "PR No Ordinary Training Studio": "Title: PR No Ordinary Training | Pero . Meta Description: PR No Ordinary Training, Pero. 159 likes. Personal Coach. Heading: ", "Multiprint": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "LR Health & Beauty Italia": "Title: LR Health & Beauty Italia. Meta Description: LR Health & Beauty Italia. 25,354 likes · 102 talking about this. ℳ𝑜𝓇𝑒 𝓆𝓊𝒶𝓁𝒾𝓉𝓎 𝒻𝑜𝓇 𝓎𝑜𝓊𝓇 𝓁𝒾𝒻𝑒.
# 🧖🏽‍♀️ Beauty specialists | Wellbeing | Nutrition
# 🪴 Aloe.... Heading: ", "Team Russo": "Title: Team Russo - Remax Class | Pero . Meta Description: Team Russo - Remax Class, Pero, Lombardia. 408 likes · 14 were here. Servizi Immobiliari da oltre vent’anni.
#
# 📍Pero (MI) Via Sempione 73
# 📍Milano Via.... Heading: ", "Malià": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "5Min S&S": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "Tempocasa Pero": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "Pero": "Title: Pero. Meta Description: . Heading: ", "Autoscuola Pero S.a.s": "Title: Autoscuola Pero | Pero . Meta Description: Autoscuola Pero, Pero, Italy. 73 likes · 1 was here. Pagina della scuola guida di Pero, metti mi piace per tenerti aggiornato sui prezzi delle patenti e.... Heading: ", "Farmacia Vittoria": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "
# Servizio di riparazione autoveicoli, tagliandi certificati, diagnosi.... Heading: ", "Villamark Marcatura - Villa Luigi & Figlio Srl": "Title: Villamark Marcatura - Villa Luigi & Figlio Srl | Pero . Meta Description: Villamark Marcatura - Villa Luigi & Figlio Srl, Pero, Italy. 107 likes · 1 was here. Vendita timbri, consulenza per marcare: fornitura servizi per.... Heading: ", "Usatokay - Mercatino dell'Usato": "Title: Usatokay | Pero . Meta Description: Usatokay, Pero, Lombardia. 588 likes · 1 was here. 🛒 Compriamo Oggetti  Vintage&Design
# 👜 Vendiamo Oggetti e Abbigliamento 📺
# STIAMO LAVORANDO PER CERCARE.... Heading: ", "Timberland": "Title: Timberland | Pero . Meta Description: Timberland, Pero, Italy. 130 likes · 48 were here. Fashion Designer. Heading: ", "DACAN": "Title: DACAN | Pero . Meta Description: DACAN, Pero. 677 likes · 4 talking about this · 327 were here. . Heading: ", "Gramsci Car Center S.r.l": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "Action Shooting Italia": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "Bolliger Moving": "Title: Bolliger SpA | Pero . Meta Description: Bolliger SpA, Pero. 18 likes · 1 talking about this. Traslochi nazionali, internazionali e industriali.
# Fine art e Relocation.. Heading: ", "Easy&Fast": "Title: Easy&Fast | Pero . Meta Description: Easy&Fast, Pero, Lombardia. 52 likes. Siamo una giovane realtà logistica specializzata nella consegna multigiornaliera.. Heading: ", "Santoemma Srl": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "Termostahl srl - tempra per induzione": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "G.T.R. Car Service": "Title: Gtr Car Service. Meta Description: . Heading: ", "Deltacon Ricerca e Sviluppo": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "Evoluzione Parrucchieri": "Title: Evoluzione Parrucchieri. Meta Description: . Heading: ", "Urban Wall - Milano Climbing Factory": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "Impresa Montali srl": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "SGS Comunicazione": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "Milano Sign": "Title: Milano Sign | Pero . Meta Description: Milano Sign, Pero, Italy. 61 likes · 2 were here. Siamo una giovane nuova azienda costituita 2015 basata sull'esperienza
# di operatori nel settore di più.... Heading: ", "Route 41": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "DSS Trasporti Bio Pharma Solution": "Title: DSS Bio Pharma Solution | Pero . Meta Description: DSS Bio Pharma Solution, Pero, Italy. 131 likes. Trasporti dedicati, specializzati nella temperatura controllata 🌡❄️. Heading: ", "Flavourland srl": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "The Loft Milano Villapizzone": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "StoryTime - Lombardia": "Title: Stotytime_gc | Pero . Meta Description: Stotytime_gc, Pero, Italy. 52 likes · 2 talking about this. Aiuto imprenditori, blogger, artigiani, professionisti.... lomabrdi a farsi conoscere meglio.... Heading: ", "Rhiag Group": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "Vimercati S.p.A.": "Title: Vimercati S.p.a.. Meta Description: . Heading: ", "Consorzio Insiamo": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "The Gate": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "Europatarghe srl": "Title: Europatarghe srl | Pero . Meta Description: Europatarghe srl, Pero, Italy. 195 likes. produzione targhe. Heading: ", "Matiba digital marketing": "Title: Facebook. Meta Description: . Heading: ", "Detente et Beaute": "Title: Détente et Beauté | Pero . Meta Description: Détente et Beauté, Pero, Italy. 4 likes · 1 was here. Health/beauty. Heading: ", "Distilleria Artigianale Milano": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "SAMA di Massimo Santacaterina": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "Bar Bijou Caffetteria": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "Presspoint": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "Saltafoss": "Title: Log into Facebook. Meta Description: Log into Facebook to start sharing and connecting with your friends, family, and people you know.. Heading: ", "
ine Laser e Timbri: http://www.villamark.it/ , Bolliger - Traslochi Internazionali e Relocation: http://www.bolligermoving.com/ , Usatokay - Mercatino dell'Usato: http://www.usatokay.it/ , Timberland: https://www.timberland.it , DACAN: No website Found , Gramsci Car Center S.r.l: http://www.gramscicarcenter.it/ , Action Shooting Italia: http://www.actionshooting.eu/ , Bolliger Moving: https://www.bolligermoving.com/ , Gerol Srl: https://www.gerol.it/ , Easy&Fast: http://www.easyandfastlog.it/ , Santoemma Srl: http://www.santoemma.com/ , Metal Tech: https://www.inferriatemetaltech.com/ , Termostahl srl - tempra per induzione: https://www.termostahl.it/it/ , Hertz Autonoleggio - Milan,pero - Bricoman HLE: https://www.hertz.it/rentacar/location/italia/milano/MILC01 , G.T.R. Car Service: https://gtrcarservice.com , Deltacon Ricerca e Sviluppo: http://www.deltacon.it/ , Evoluzione Parrucchieri: No website Found , Urban Wall - Milano Climbing Factory: https://www.urbanwall.it ...

# %%
scraped_count = 0
total_websites = len(websites)
progress_step = max(1, total_websites // 20)  # 5% step

def scrape_site_wrapper(args):
    global scraped_count
    place, site = args
    if site is not None and len(site) > 0 and site[0] != "No website Found":
        try:
            scraped_content = scrape_website(site[0])
            result = (place, scraped_content if scraped_content else "Scraping Failed")
        except Exception:
            result = (place, "Scraping Failed")
    else:
        result = (place, "No website Found")
    scraped_count += 1
    if scraped_count % progress_step == 0 or scraped_count == total_websites:
        percent = (scraped_count / total_websites) * 100
        print(f"{scraped_count}/{total_websites} ({percent:.1f}%) websites scraped")
    return result

with concurrent.futures.ThreadPoolExecutor(max_workers=3000) as executor:
    results = list(executor.map(scrape_site_wrapper, websites.items()))

scraped_websites = dict(results)
print(scraped_websites)
# Out:
# Failed to Scrape: http://www.casualstore.net/: HTTPConnectionPool(host='www.casualstore.net', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000206073EF3B0>: Failed to resolve 'www.casualstore.net' ([Errno 11001] getaddrinfo failed)"))
# Failed to Scrape: : Invalid URL '': No scheme supplied. Perhaps you meant https://?
# 12/242 (5.0%) websites scraped
# Failed to Scrape: http://Www.noordinarytraining.com/: HTTPConnectionPool(host='www.noordinarytraining.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x000002060AF9EB70>: Failed to resolve 'www.noordinarytraining.com' ([Errno 11001] getaddrinfo failed)"))
# Failed to Scrape: http://www.actionshooting.eu/: HTTPConnectionPool(host='www.actionshooting.eu', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x000002060A50D760>: Failed to resolve 'www.actionshooting.eu' ([Errno 11001] getaddrinfo failed)"))Failed to Scrape: http://it.pointservice.net: HTTPConnectionPool(host='it.pointservice.net', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x000002060A4DE9C0>: Failed to resolve 'it.pointservice.net' ([Errno 11001] getaddrinfo failed)"))
#
# Failed to Scrape: http://www.millybar.it/: HTTPConnectionPool(host='www.millybar.it', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x000002060C7BCBC0>: Failed to resolve 'www.millybar.it' ([Errno 11001] getaddrinfo failed)"))
# 24/242 (9.9%) websites scraped
# Failed to Scrape: www.vimercati.com: Invalid URL 'www.vimercati.com': No scheme supplied. Perhaps you meant https://www.vimercati.com?
# Failed to Scrape: http://www.risingsun.it/: HTTPConnectionPool(host='www.risingsun.it', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x000002060A821850>: Failed to resolve 'www.risingsun.it' ([Errno 11001] getaddrinfo failed)"))
# Failed to Scrape
title: homepage | Malià - l' officina della sarta. Meta Description: Malià l' officina della sarta è un' idea nata dall' esperienza familiare di attività svolta nell' ambito della sartoria artigianale di cui vuole promuovere i. Heading: ", '5Min S&S': 'Title: About - 5min. is the time it takes to fall in love. Meta Description: . Heading: ', 'Tempocasa Pero': 'Scraping Failed', 'Pero': 'No website Found', 'Autoscuola Pero S.a.s': 'No website Found', 'Farmacia Vittoria': 'No website Found', 'Eurogreen Fiori': 'Scraping Failed', 'Western Union': 'Title: Western Union: Il tuo partner nel trasferimento di Denaro. Meta Description: Scegli Western Union come tuo partner ideale nel trasferimento di denaro. AffidabilitÃ\xa0 e esperienza al servizio delle tue esigenze finanziarie.. Heading: Unisciti a milioni di clienti che si affidano a noi per inviare denaro dal 1851', 'Libri e Giardini': 'No website Found', 'Pizzeria Sempione Da Lorenzo E Ivan | Pero': 'No website Found', 'Easyoga & Fun': 'No website Found', 'Laurita Michele': 'Scraping Failed', 'Magistroni Alessio': 'Title: Homepage - Modellismo News. Meta Description: Lifestyle. Heading: ', 'Puro Tango': 'No website Found', 'Pero (metropolitana di Milano)': 'Title: Pero (stacja metra) – Wikipedia, wolna encyklopedia. Meta Description: . Heading: Pero (stacja metra)', 'FCW Wrestling': 'Title: FCW Wrestling - YouTube. Meta Description: Est. 2005 - “Frontier Championship Wrestling "...una storia decennale di un\'accademia vecchio stampo che trova la sua chiave in impegno e passione..."L’Accad.... Heading: ', 'Scuola di musica giorgio canali 3': 'Title: Sito privato. Meta Description: . Heading: Sito privato', 'Rising Sun Wrestling Promotion': 'Scraping Failed', 'Matrix Informatica Srl': 'Scraping Failed', 'Ferramenta Allegri': 'No website Found', 'SOS Monopattini Elettrici': 'Title: Assistenza Monopattini Milano - ASSISTENZA MONOPATTINI ELETTRICI MILANO E PROVINCIA. Meta Description: Assistenza Monopattini Milano : se il tuo monopattino necessita di assistenza, noi siamo specializzati in riparazioni monopattini a Milano. Heading: Assistenza Monopattini Milano e provincia;Riparazione monopattino elettrico Milano', 'ugly.milano': 'Ti ...

# %%
category_keywords = {
    # Accommodation
    "accommodation-hotel":          ["hotel", "albergo"],
    "accommodation-hostel":         ["hostel", "ostello"],
    "accommodation-motel":          ["motel"],
    "accommodation-resort":         ["resort"],
    "accommodation-bed_and_breakfast": ["bed and breakfast", "b&b"],

    # Food & Drink
    "eat_and_drink-restaurant":     ["restaurant", "ristorante", "trattoria", "osteria", "pizzeria", "pizza"],
    "eat_and_drink-cafe":           ["cafe", "caffè", "coffee shop", "caffetteria"],
    "eat_and_drink-bar":            ["bar", "pub", "wine bar", "enoteca"],
    "retail-food-bakery":           ["bakery", "panificio", "forno"],
    "retail-food-ice_cream_shop":   ["ice cream", "gelateria"],
    "retail-food-pastry_and_cake_shop": ["pastry shop", "pasticceria"],
    "eat_and_drink-fast_food":      ["fast food", "takeaway", "kebab", "shawarma", "sushi", "taco", "burger", "hot dog"],
    "eat_and_drink-tea_room":       ["tea room", "tearoom"],
    "eat_and_drink-juice_bar":      ["juice bar", "smoothie"],

    # Retail
    "retail":                       ["shop", "store", "market", "boutique", "emporio", "negozio"],
    "retail-food-supermarket":      ["supermarket", "grocery", "ipermercato"],
    "health_and_medical-pharmacy":  ["pharmacy", "farmacia"],
    "retail-books_stationery_music_and_film-book_shop": ["bookstore", "libreria", "librairie"],
    "retail-clothing_and_accessories-clothing_store":    ["clothing store", "abbigliamento", "fashion"],
    "retail-clothing_and_accessories-jewelry_and_watch_store": ["jewelry", "gioielleria"],
    "retail-clothing_and_accessories-shoe_store":        ["shoe store", "calzature"],
    "retail-toys_and_games_store":     ["toy store", "giocattoli"],
    "retail-home_and_garden-florist":  ["flower shop", "florist", "fioraio"],
    "retail-electronics-consumer_electronics_store": ["electronics store", "elettronica"],
    "retail-home_and_garden-hardware_store": ["hardware store", "ferramenta"],
    "retail-department_store":         ["department store", "grande magazzino"],
    "retail-shopping_center_and_mall":["mall", "shopping center", "centro commerciale"],
    "retail-beverage_store-wine_and_spirits_store": ["wine shop", "enoteca"],
    "retail-books_stationery_music_and_film-newsagent_and_kiosk": ["newsstand", "edicola"],
    "retail-tobacconist":              ["tobacco shop", "tabaccheria", "tabacchi"],

    # Arts & Entertainment
    "attractions_and_activities-museum":     ["museum", "museo"],
    "arts_and_entertainment-movie_theater": ["cinema", "movie theater"],
    "arts_and_entertainment-performing_arts_theater":["theater", "teatro"],
    "attractions_and_activities-art_gallery": ["art gallery", "galleria d'arte"],
    "arts_and_entertainment-topic_concert_venue":["music venue", "concert hall"],
    "arts_and_entertainment-night_club":    ["nightclub", "discoteca", "disco"],
    "attractions_and_activities-amusement_park":["amusement park", "theme park"],
    "attractions_and_activities-aquarium":   ["aquarium", "acquario"],
    "attractions_and_activities-zoo":        ["zoo", "bioparco"],
    "arts_and_entertainment-bowling_alley":  ["bowling", "bowling alley"],
    "active_life-sports_and_recreation_venue-gym_and_fitness_center": ["gym", "fitness", "palestra"],
    "active_life-sports_and_recreation_venue-stadium_and_arena": ["stadium", "arena", "stadio"],
    "active_life-sports_and_recreation_venue-sports_center": ["sports centre", "centro sportivo"],
    "active_life-sports_and_recreation_venue-public_swimming_pool": ["swimming pool", "piscina"],
    "attractions_and_activities-playground": ["playground", "parco giochi"],
    "active_life-marina":                  ["marina", "porto"],
    "attractions_and_activities-beach":     ["beach", "spiaggia"],
    "attractions_and_activities-historic_site": ["historic site", "monument", "monumento"],
    "attractions_and_activities-winery":    ["winery", "cantina"],
    "attractions_and_activities-brewery":   ["brewery", "birrificio"],
    "arts_and_entertainment-arcade":       ["arcade", "sala giochi"],
    "arts_and_entertainment-casino":       ["casino", "casinò"],
    "arts_and_entertainment-music_school": ["music school", "scuola di musica"],
    "attractions_and_activities-library":   ["library", "biblioteca"],
    "art_studios":                         ["art studio", "studio d'arte"],

    # Health & Medical
    "health_and_medical-hospital":         ["hospital", "ospedale"],
    "health_and_medical-clinic_and_medical_center": ["clinic", "ambulatorio", "poliambulatorio"],
    "health_and_medical-dentist":          ["dentist", "dentista"],
    "health_and_medical-doctor":           ["doctor", "physician", "medico"],
    "pets-veterinarian":                   ["veterinary", "vet", "veterinario"],
    "health_and_medical-optician":         ["optician", "ottica"],
    "health_and_medical-physiotherapist":  ["physio", "physiotherapist", "fisioterapista"],
    "health_and_medical-pharmacy":         ["pharmacy", "farmacia"],
    "health_and_medical-diagnostic_lab":   ["laboratory", "laboratorio"],
    "health_and_medical-urgent_care":      ["urgent care", "pronto soccorso"],
    "health_and_medical-medical_supply":   ["medical supply", "dispositivi medici"],

    # Education & Public Services
    "education-college_university":        ["university", "college", "università", "ateneo", "politecnico"],
    "education-school":                    ["school", "scuola", "liceo", "istituto"],
    "education-specialty_school-driving_school": ["driving school", "autoscuola"],
    "education-school-preschool_and_kindergarten": ["kindergarten", "nursery", "asilo"],
    "public_service_and_government-post_office": ["post office", "ufficio postale", "poste italiane"],
    "public_service_and_government-police_station": ["police", "polizia", "carabinieri", "questura"],
    "public_service_and_government-fire_station": ["fire station", "vigili del fuoco"],
    "public_service_and_government-embassy":["embassy", "ambasciata"],
    "public_service_and_government-consulate":["consulate", "consolato"],
    "public_service_and_government-government_services-city_hall":["city hall", "municipio", "comune"],
    "public_service_and_government-courthouse":["courthouse", "tribunale"],
    "public_service_and_government-library":["library", "biblioteca"],

    # Finance & Real Estate
    "financial_service-bank_credit_union":["bank", "banca", "ATM", "bancomat"],
    "financial_service-insurance_agency":["insurance", "assicurazioni"],
    "real_estate-real_estate_agent_and_broker":["real estate", "agenzia immobiliare"],
    "real_estate-property_management":["property management", "gestione immobiliare"],
    "financial_service-ATM":["ATM", "bancomat"],
    "financial_service-stock_broker":["broker", "borsa"],

    # Transportation & Automotive
    "travel-airport":                      ["airport", "aeroporto"],
    "travel-transportation-rail_station":  ["train station", "stazione ferroviaria"],
    "travel-transportation-bus_station":   ["bus station", "autostazione"],
    "travel-transportation-bus_stop":      ["bus stop", "fermata autobus"],
    "travel-transportation-subway_station":["metro station", "subway station", "stazione metro"],
    "travel-transportation-taxi_limo_and_shuttle_service-taxi_stand":["taxi stand", "posteggio taxi"],
    "automotive-gas_station":             ["gas station", "petrol station", "distributore di benzina"],
    "travel-road_structures_and_services-parking":["parking", "parcheggio", "autorimessa"],
    "automotive-automotive_services_and_repair-car_wash_and_detail":["car wash", "autolavaggio"],
    "automotive-automotive_services_and_repair":["car repair", "mechanic", "officina", "carrozzeria"],
    "automotive-automotive_dealer":["car dealer", "concessionaria auto"],
    "automotive-automotive_parts_and_accessories-tire_shop":["tire shop", "gommista"],

    # Personal & Professional Services
    "beauty_and_spa-hair_salon":["hair salon", "parrucchiere", "barber"],
    "beauty_and_spa-beauty_salon":["beauty salon", "centro estetico", "istituto di bellezza"],
    "professional_services-laundry_services":["laundry", "lavanderia", "launderette"],
    "professional_services-funeral_services_and_cemeteries-funeral_service":["funeral home", "onoranze funebri"],
    "professional_services-funeral_services_and_cemeteries-cemetery":["cemetery", "cimitero"],
    "professional_services-dry_cleaning":["dry cleaning", "lavasecco"],
    "professional_services-pet_grooming":["pet grooming", "toelettatura animali"],
    "professional_services-photographer":["photographer", "fotografo"],
    "professional_services-legal_services":["lawyer", "avvocato", "studio legale"],
    "professional_services-accounting":["accountant", "commercialista"],

    # Recreation & Leisure
    "attractions_and_activities-park":["park", "parco", "giardino pubblico"],
    "attractions_and_activities-beach":["beach", "spiaggia"],
    "attractions_and_activities-hiking_trail":["trail", "sentiero"],
    "attractions_and_activities-campground":["campground", "campeggio"],
    "attractions_and_activities-ski_resort":["ski resort", "stazione sciistica"],

    # Repeat or synonym expansions until 150+ entries total...
}

# %%
RULES = [
    (
        lambda n, w, s, kws=keywords: any(kw in (n or "").lower() or kw in (w or "").lower() or kw in (s or "").lower() for kw in kws),
        category
    )
    for category, keywords in category_keywords.items()
]

# %%
def rule_based_category(poi_name, website_text, social_text):
    name = (poi_name or "").lower()
    web  = (website_text or "").lower()
    soc  = (social_text or "").lower()
    for test_fn, category in RULES:
        try:
            if test_fn(name, web, soc):
                return category
        except Exception:
            continue
    return None

# Apply the rules to all POIs in your scraped data
poi_rule_categories = {}
for poi, site_text in scraped_websites.items():
    # Combine all social scraped content for this POI into one string
    social_entries = scraped_socials_content.get(poi, [])
    combined_social = " ".join(next(iter(d.values()), "") for d in social_entries)
    poi_rule_categories[poi] = rule_based_category(poi, site_text, combined_social)

# Inspect the mapping of POI names to their rule-based categories
print(poi_rule_categories)
# Out:
# {'Parco Nicolas': 'attractions_and_activities-park', 'Edimol Sas': None, 'Casual Store money transfer': 'retail', 'Molino Dorino': None, 'Atlassib': None, 'CSC - Casa salvadorena Cultural': None, 'Prodent Italia': None, 'Saldoplast': None, 'Swiss DolorClast Italia': 'arts_and_entertainment-night_club', 'Mud Museum - Open Space': 'attractions_and_activities-museum', 'PR No Ordinary Training Studio': None, 'Multiprint': 'retail-clothing_and_accessories-clothing_store', 'LR Health & Beauty Italia': None, 'Team Russo': 'eat_and_drink-bar', 'Malià': 'automotive-automotive_services_and_repair', '5Min S&S': None, 'Tempocasa Pero': None, 'Pero': None, 'Autoscuola Pero S.a.s': 'education-school', 'Farmacia Vittoria': 'health_and_medical-pharmacy', 'Eurogreen Fiori': None, 'Western Union': None, 'Libri e Giardini': None, 'Pizzeria Sempione Da Lorenzo E Ivan | Pero': 'eat_and_drink-restaurant', 'Easyoga & Fun': 'eat_and_drink-bar', 'Laurita Michele': 'beauty_and_spa-hair_salon', 'Magistroni Alessio': None, 'Puro Tango': None, 'Pero (metropolitana di Milano)': None, 'FCW Wrestling': None, 'Scuola di musica giorgio canali 3': 'arts_and_entertainment-music_school', 'Rising Sun Wrestling Promotion': None, 'Matrix Informatica Srl': None, 'Ferramenta Allegri': 'retail-home_and_garden-hardware_store', 'SOS Monopattini Elettrici': None, 'ugly.milano': 'arts_and_entertainment-night_club', 'Eni Station': None, 'Penny': 'retail', 'Arcaplanet': 'retail', 'Maxi Zoo Italia': 'retail', 'Blustar Car': None, 'Mercedes-Benz Service': 'pets-veterinarian', 'Pizza e Brace': 'eat_and_drink-restaurant', 'Milly bar': 'eat_and_drink-bar', 'Autostradale': None, 'X-Moto': None, 'MABA Shopping Pero': 'retail', 'Safetykleen Italia - Soluzioni complete per il lavaggio pezzi': None, 'Morini Rent Milano Fiera - Pero - Noleggio Auto e Furgoni': None, 'Dott.ssa Simona Adelaide Martini Psicologa-Psicoterapeuta Emdr': None, 'Matcro Lab di Dott. Mattia Crosta': None, 'REB- Riparazioni contachilometri Milano': None, 'Speedy Car Snc': None, 'Cogepro Business Center': None, 'Motormobile Rovida': 'automotive-automotive_services_and_repair', 'Villamark Marcatura - Villa Luigi & Figlio Srl': None, 'VILLA L. & FIGLIO srl - Macchine Laser e Timbri': None, 'Bolliger - Traslochi Internazionali e Relocation': None, "Usatokay - Mercatino dell'Usato": 'eat_and_drink-bar', 'Timberland': 'retail-clothing_and_accessories-clothing_store', 'DACAN': None, 'Gramsci Car Center S.r.l': 'automotive-automotive_services_and_repair', 'Action Shooting Italia': None, 'Bolliger Moving': None, 'Gerol Srl': None, 'Easy&Fast': 'eat_and_drink-bar', 'Santoemma Srl': None, 'Metal Tech': None, 'Termostahl srl - tempra per induzione': None, 'Hertz Autonoleggio - Milan,pero - Bricoman HLE': None, 'G.T.R. Car Service': 'automotive-automotive_services_and_repair', 'Deltacon Ricerca e Sviluppo': 'eat_and_drink-fast_food', 'Evoluzione Parrucchieri': None, 'Urban Wall - Milano Climbing Factory': 'active_life-sports_and_recreation_venue-gym_and_fitness_center', 'Impresa Montali srl': None, 'SGS Comunicazione': 'eat_and_drink-bar', 'VetroCar': 'pets-veterinarian', 'Milano Sign': None, 'Route 41': None, 'DSS Trasporti Bio Pharma Solution': 'active_life-marina', 'Flavourland srl': None, 'Dss Bio Pharma Solution Trasporti': 'active_life-marina', 'Dss Bio-Pharma': 'active_life-marina', 'Bellinzoni SRL': None, 'The Loft Milano Villapizzone': 'active_life-sports_and_recreation_venue-gym_and_fitness_center', 'StoryTime - Lombardia': 'eat_and_drink-bar', 'Rhiag Group': None, 'Vimercati S.p.A.': None, 'Consorzio Insiamo': 'retail', 'The Gate': None, 'Europatarghe srl': None, 'Matiba digital marketing': 'retail', 'Detente et Beaute': None, 'Distilleria Artigianale Milano': None, 'SAMA di Massimo Santacaterina': 'eat_and_drink-bar', 'Bar Bijou Caffetteria': 'eat_and_drink-cafe', 'Presspoint': None, 'Saltafoss': None, 'Reputation Manager S.p.A. - Ingegneria Reputazionale': 'eat_and_drink-bar', 'Payer': None, 'Dubini Traslochi E S ...

# %%
# Set up the API key
api_key = "AIzaSyBTTIggzhUhQVFZglOG1-PZF9xO3PRb-kY"

# %%
import google.generativeai as genai
genai.configure(api_key=api_key)
model = genai.GenerativeModel("gemini-2.0-flash")
context = "You are a Category Suggestion Agent. Your job is to read a POI record that I provide you with that consists of the POI name, rule-based search results and data scraped from its website and socials. Now using this propose an category for it which is as detailed as possible (Outputing 'italian restaurant' instead of 'restaurant') using its name, rule based search and web/ socials scraped information, just categorize until you are sure about the category."+\
        f"These are all the categories in the schema in a JSON file that has all the categories in the form as a tree: {category_tree}." +\
        f"While categorizing, I expect you to traverse the category tree and categorize level by level. for example, if you are categorizing a restaurant, you should first categorize it as 'eat_and_drink', then as 'restaurant', and finally as 'italian restaurant' if applicable."+\
        "I am going to provide you with all the POIs names with the website scraped information, I will provided the names and website scraped information in this format: 'name': 'website scraped information'" +\
        f"These are the POIs with the website scraped information: {scraped_websites}" +\
        "I am also going to provide you with all the POIs names with the rule-based search results, I will provided the names and rule-based search results in this format: 'name': 'rule-based search category prediction'" +\
        f"These are the POIs with the rule-based search results: {poi_rule_categories}" +\
        "Finally, I am going to provide you with all the POIs names with the socials scraped information, I will provided the names and socials scraped information in this format: 'name': 'socials scraped information'" +\
        f"These are the POIs with the socials scraped information: {scraped_socials_string}" +\
        "Provide me with a category that best sutes the primary category for these POIs from the list of categories I provided you with. Choose as detailed as possible and ONLY choose the categories that you are mostly sure about"+\
        "The response should be in this format: 'name': 'predicted category & confidance percentage'. Be as honest as possible and if you are not sure about the category please say so. Do not provide any other information or explanation, just the POI's name and their predicted categories."+\
        "You do not need to provide it in a JSON format, just provide it in a string format, one line for each POI. Do not provide any other information or explanation, just the POI's name and their predicted categories."

# %%
# Generate content using the model
response = model.generate_content(context)
print(response.text)
# Out:
# Parco Nicolas: park & 70%
# Edimol Sas: No predicted category
# Casual Store money transfer: financial_service-money_transfer_services & 50%
# Molino Dorino: No predicted category
# Atlassib: No predicted category
# CSC - Casa salvadorena Cultural: cultural_center & 60%
# Prodent Italia: medical_supply-dental_supply_store & 50%
# Saldoplast: business_manufacturing_and_supply-plastic_manufacturer & 50%
# Swiss DolorClast Italia: health_and_medical-physical_therapy & 50%
# Mud Museum - Open Space: attractions_and_activities-museum & 70%
# PR No Ordinary Training Studio: active_life-sports_and_fitness_instruction-fitness_trainer & 50%
# Multiprint: retail-arts_and_crafts-art_supply_store & 50%
# LR Health & Beauty Italia: beauty_and_spa & 60%
# Team Russo: real_estate_agent & 50%
# Malià: sewing_and_alterations & 50%
# 5Min S&S: No predicted category
# Tempocasa Pero: real_estate_agent & 50%
# Pero: No predicted category
# Autoscuola Pero S.a.s: education-driving_school & 70%
# Farmacia Vittoria: health_and_medical-pharmacy & 70%
# Eurogreen Fiori: retail-flowers_and_gifts_shop-florist & 50%
# Western Union: financial_service-money_transfer_services & 70%
# Libri e Giardini: retail-books_mags_music_and_video-bookstore & 50%
# Pizzeria Sempione Da Lorenzo E Ivan | Pero: eat_and_drink-pizza_restaurant & 70%
# Easyoga & Fun: active_life-yoga_studio & 50%
# Laurita Michele: beauty_and_spa-hair_salon & 70%
# Magistroni Alessio: No predicted category
# Puro Tango: arts_and_entertainment-dance_club & 50%
# Pero (metropolitana di Milano): travel-transportation-metro_station & 50%
# FCW Wrestling: active_life-sports_club_and_league & 50%
# Scuola di musica giorgio canali 3: education-music_school & 70%
# Rising Sun Wrestling Promotion: No predicted category
# Matrix Informatica Srl: it_service_and_computer_repair & 50%
# Ferramenta Allegri: retail-home_and_garden-hardware_store & 70%
# SOS Monopattini Elettrici: automotive_services_and_repair-motorcycle_repair & 50%
# ugly.milano: retail-leather_goods & 50%
# Eni Station: automotive-gas_station & 50%
# Penny: retail-supermarket & 70%
# Arcaplanet: retail-pet_store & 70%
# Maxi Zoo Italia: retail-pet_store & 70%
# Blustar Car: automotive_dealer-car_dealer & 50%
# Mercedes-Benz Service: automotive_services_and_repair & 70%
# Pizza e Brace: eat_and_drink-pizza_restaurant & 70%
# Milly bar: eat_and_drink-bar & 70%
# Autostradale: travel-bus_service & 50%
# X-Moto: automotive_dealer-motorcycle_dealer & 50%
# MABA Shopping Pero: retail-shopping_center & 50%
# Safetykleen Italia - Soluzioni complete per il lavaggio pezzi: business_to_business & 50%
# Morini Rent Milano Fiera - Pero - Noleggio Auto e Furgoni: travel-rental_service-car_rental_agency & 50%
# Dott.ssa Simona Adelaide Martini Psicologa-Psicoterapeuta Emdr: health_and_medical-counseling_and_mental_health-psychologist & 50%
# Matcro Lab di Dott. Mattia Crosta: No predicted category
# REB- Riparazioni contachilometri Milano: automotive_services_and_repair & 50%
# Speedy Car Snc: No predicted category
# Cogepro Business Center: private_establishments_and_corporates-corporate_office & 50%
# Motormobile Rovida: automotive-automotive_repair & 70%
# Villamark Marcatura - Villa Luigi & Figlio Srl: business_equipment_and_supply & 50%
# VILLA L. & FIGLIO srl - Macchine Laser e Timbri: business_equipment_and_supply & 50%
# Bolliger - Traslochi Internazionali e Relocation: home_service-movers & 50%
# Usatokay - Mercatino dell'Usato: retail-thrift_store & 50%
# Timberland: retail-shoe_store & 70%
# DACAN: No predicted category
# Gramsci Car Center S.r.l: automotive-automotive_repair & 70%
# Action Shooting Italia: active_life-shooting_range & 50%
# Bolliger Moving: home_service-movers & 50%
# Gerol Srl: business_to_business & 50%
# Easy&Fast: business_to_business-business_storage_and_transportation & 50%
# Santoemma Srl: No predicted category
# Metal Tech: No predicted category
# Termostahl srl - tempra per induzione: No predicted category
# Hertz Autonoleggio - Milan,pero - Bricoman HLE: travel-rental_service-car_rental_agency & 50%
# G.T.R. Car Service: automotive-auto_body_shop & 70%
# Deltacon Ricerca e Sviluppo: education & 50%
# Evoluzione Parrucchieri: beauty_and_spa-hair_salon & 50%
# Urban Wall - Milano Climbing Factory: active_life-sports_and_recreation_venue-rock_climbing_gym & 70%
# Impresa Montali srl: home_service-contractor & 50%
# SGS Comunicazione: professional_services-advertising_agency & 50%
# VetroCar: automotive_services_and_repair-auto_glass_service & 50%
# Milano Sign: business_advertising-business_signage & 50%
# Route 41: No predicted category
# DSS Trasporti Bio Pharma Solution: business_to_business-business_storage_and_transportation-freight_and_cargo_service & 50%
# Flavourland srl: No predicted category
# Dss Bio Pharma Solution Trasporti: business_to_business-business_storage_and_transportation-freight_and_cargo_service & 50%
# Dss Bio-Pharma: business_to_business-business_storage_and_transportation-freight_and_cargo_service & 50%
# Bellinzoni SRL: No predicted category
# The Loft Milano Villapizzone: active_life-sports_and_recreation_venue-gym & 70%
# StoryTime - Lombardia: No predicted category
# Rhiag Group: No predicted category
# Vimercati S.p.A.: No predicted category
# Consorzio Insiamo: retail-shopping_center & 50%
# The Gate: No predicted category
# Europatarghe srl: automotive_parts_and_accessories & 50%
# Matiba digital marketing: professional_services-internet_marketing_service & 70%
# Detente et Beaute: beauty_and_spa & 70%
# Distilleria Artigianale Milano: retail-beer_wine_and_spirits & 50%
# SAMA di Massimo Santacaterina: eat_and_drink-restaurant_equipment_and_supply & 50%
# Bar Bijou Caffetteria: eat_and_drink-cafe & 70%
# Presspoint: No predicted category
# Saltafoss: retail-sporting_goods-bicycle_shop & 50%
# Reputation Manager S.p.A. - Ingegneria Reputazionale: professional_services-public_relations & 50%
# Payer: No predicted category
# Dubini Traslochi E Servizi Srl: home_service-movers & 50%
# Mahamevnawa Buddhist Meditation Monastery: religious_organization-buddhist_temple & 50%
# Esselunga: retail-supermarket & 70%
# Parrocchia San Leonardo: religious_organization-church_cathedral-catholic_church & 50%
# Gruppo Sirio: arts_and_entertainment-social_club & 50%
# Circolo Fotografico Trevisani: arts_and_entertainment-social_club & 50%
# Circolo SEL - E. Ragionieri: public_service_and_government-political_organization & 50%
# ASD Zonaotto: active_life-sports_club_and_league & 50%
# Balzoo - Banco Italiano Zoologico APS: attractions_and_activities-zoo & 50%
# Faridamore: professional_services-cleaning_services & 50%
# Skilifting & Bike: retail-sporting_goods-ski_and_snowboard_shop & 50%
# Leone: No predicted category
# Mandelli materassi: retail-home_and_garden-mattress_store & 50%
# Bar fratelli Guido: eat_and_drink-bar & 70%
# La Pergola: eat_and_drink-restaurant & 70%
# Trattoria Italo Cinese: eat_and_drink-restaurant & 70%
# Autolavaggio SM2: automotive-automotive_services_and_repair-car_wash & 70%
# Joe Eze Foundation: public_service_and_government-organization-social_service_organizations-charity_organization & 50%
# Esso Milano Via Gallarate: automotive-gas_station & 50%
# SisalPay: financial_service & 70%
# Bardelli Taglio Laser: business_to_business & 50%
# Kebap House: eat_and_drink-doner_kebab & 50%
# Vita Studio: No predicted category
# Vetrofanie Milano sas di Pulici Paolo: No predicted category
# Strane Officine: No predicted category
# Non Solo Cross: automotive_parts_and_accessories & 50%
# Autoclub S.N.C.: No predicted category
# Lucia Pascale eco designer: retail-clothing_store & 50%
# Mas Metano: automotive-gas_station & 50%
# ODStore: retail & 70%
# Gruppo Grancasa: retail-home_and_garden & 50%
# Ristorante La Rosa Incantata: eat_and_drink-restaurant & 70%
# La Rosa incantata: eat_and_drink-restaurant & 70%
# Grancasa: retail-furniture_store & 50%
# Tecnomat: retail-home_improvement_store & 50%
# Bricoman: retail-home_improvement_store & 50%
# MAGIA Coiffeur by Lella: beauty_and_spa-hair_salon & 50%
# Coiffeur Pour Dame Di Attanasio Graziella: beauty_and_spa-hair_salon & 70%
# Restaurant One: eat_and_drink-restaurant & 70%
# Merbag S.p.a.: automotive_dealer-car_dealer & 50%
# Due Bacchette: No predicted category
# Cinque Stelle: eat_and_drink-restaurant & 70%
# TESL: No predicted category
# Gazzotti Spa: business_to_business-business_storage_and_transportation-freight_and_cargo_service & 50%
# Carrozzeria La Moderna: automotive-auto_body_shop & 70%
# La Moderna s.r.l: automotive-auto_body_shop & 70%
# Bar Atlantic: eat_and_drink-bar & 70%
# Hamerica’s Cascina merlata bloom : eat_and_drink-american_restaurant & 70%
# Excélsa Italia: retail-home_and_garden & 50%
# Rossopomodoro Cascina Merlata: eat_and_drink-pizza_restaurant & 70%
# Intimissimi: retail-clothing_store-lingerie_store & 70%
# Tezenis: retail-clothing_store & 70%
# Panino Giusto: eat_and_drink-sandwich_shop & 50%
# Calzedonia: retail-clothing_store & 70%
# Bun Burgers - Merlata Bloom: eat_and_drink-burger_restaurant & 70%
# Corte Futura: real_estate & 50%
# Al Merlata Bloom Mall - lo Shopping Center di Milano: retail-shopping_center & 70%
# Triumph of Dreams: No predicted category
# Cascina Merlata: No predicted category
# Citta Contemporanea: real_estate & 50%
# Lavanderia Fresco & Pulito: professional_services-laundry_services-laundromat & 50%
# Premium Service: No predicted category
# Piazza Giovanni Pesce: No predicted category
# Mare culturale urbano food hub: eat_and_drink-restaurant & 50%
# La Graffetta In Cascina: retail-cards_and_stationery_store & 50%
# Merlata Map Food: eat_and_drink-fast_food_restaurant & 70%
# DHL Service Point (CARTOLERIA LA GRAFFETTA): travel-transportation-shipping_center & 50%
# Gelateria Baci Sottozero: retail-food-ice_cream_shop & 70%
# UpTown Milano: No predicted category
# Studio MErlaTA: professional_services & 50%
# Family Hub - Il portale delle  opportunità: No predicted category
# Bebek Nido e Scuola dell’Infanzia Bilingue: education-preschool & 50%
# Spaziopensiero Onlus: public_service_and_government-organization-social_service_organizations & 50%
# Cascina Merlata- Community Center: public_service_and_government-community_center & 50%
# NCC Milano Atlas: travel-transportation-taxi_service & 50%
# La Yogurteria CC Merlata Bloom: eat_and_drink-ice_cream_and_frozen_yoghurt-frozen_yoghurt_shop & 50%
# InternoChicMilano CIN IT015146C2TGYDD39G: accommodation-holiday_rental_home & 50%
# Urso Impianti S.R.L.: No predicted category
# BRT Express Courier: travel-transportation-shipping_center & 50%
# Bruno Euronics - Milano: retail-electronics & 50%
# GameStop: retail-video_game_store & 50%
# Phonelab - C.C. Merlata Bloom: retail-mobile_phone_store & 50%
# Erbolario Merlata Bloom: retail-cosmetic_and_beauty_supplies & 50%
# Champion Store: retail-clothing_store & 70%
# Merbag Italia: automotive_dealer-car_dealer & 50%
# Il Mannarino: retail-food-butcher_shop & 70%
# Poke House - Cascina Merlata: eat_and_drink-poke_restaurant & 50%
# Signorvino Milano - Cascina Merlata: eat_and_drink-restaurant & 70%
# STROILI: retail-jewelry_store & 70%
# Juice Milano Merlata | Apple Premium Partner e Centro Assistenza Autorizzato Apple: electronics_repair_shop & 50%
# Mondadori Bookstore: retail-books_mags_music_and_video-bookstore & 70%
# Mango: retail-clothing_store & 70%
# Yves Rocher: retail-cosmetic_and_beauty_supplies & 70%
# Nashi Store Merlata Bloom: retail-cosmetic_and_beauty_supplies & 50%
# Intimissimi Uomo: retail-clothing_store-lingerie_store & 70%
# Kiko Milano: retail-cosmetic_and_beauty_supplies & 70%
# Inside-Out: No predicted category
# Q.re Cascina Merlata - Milano: real_estate & 50%
# Kasanova: retail-home_and_garden-home_goods_store & 70%
# Pirates Bay - Milano Merlata Bloom: eat_and_drink-restaurant & 70%
# Caruso Caffe e Bistrot: eat_and_drink-bistro & 50%
# Gioielleria Stroili: retail-jewelry_store & 70%
# Calliope: No predicted category
# IKEA Milano Cascina Merlata plan and order point: retail-furniture_store & 50%
# Vodafone Store: retail-mobile_phone_store & 70%
# Kebhouze - Merlata Bloom: eat_and_drink-doner_kebab & 50%
# Cioccolatitaliani - Merlata Bloom Milano: retail-food-desserts & 50%
# Vorwerk Point Bimby Folletto: retail-appliance_store & 50%
# Gutteridge: retail-clothing_store & 70%
# Macha Pokè Merlata: eat_and_drink-poke_restaurant & 50%
# Löwengrube Merlata Bloom Milano: eat_and_drink-german_restaurant & 50%
# Mayoral - Negozio di Abbigliamento per bambini e neonati: retail-clothing_store-children's_clothing_store & 70%
# LOG Lot Of Games - Merlata Bloom: arts_and_entertainment-arcade & 70%
# Parco pubblico Cascina Merlata: attractions_and_activities-park & 50%
# JACK & JONES: retail-clothing_store & 70%
# Primadonna Collection: retail-shoe_store & 50%
# Merlata Bloom Milano: retail-shopping_center & 70%
# Kaidor Gioiellerie: retail-jewelry_store & 50%
# Ottica GrandVision Centro Commerciale Merlata Bloom Milano: health_and_medical-optometrist & 50%
# Neat Burger: eat_and_drink-burger_restaurant & 70%
# dixie: retail-clothing_store & 70%
# Marlù Store Milano C.C Merlata Bloom: retail-jewelry_store & 70%
# GUESS: retail-clothing_store & 50%
# Jean Louis David Parrucchieri CC Merlata Bloom: beauty_and_spa-hair_salon & 70%
# MOTIVI: retail-clothing_store & 70%
# Old Wild West - Milano C.C. Merlata Bloom: eat_and_drink-american_restaurant & 70%
# The Barber&Co CC Merlata Bloom: beauty_and_spa-barber & 50%
# IMPERIAL: retail-clothing_store & 70%
# Boutique Legami: retail-cards_and_stationery_store & 50%
# OKAIDI: retail-clothing_store-children's_clothing_store & 50%
# Decathlon Milano Merlata: retail-sporting_goods & 50%
# Ramen Bar Akira: eat_and_drink-asian_restaurant-japanese_restaurant & 50%
# JD Sports: retail-sporting_goods & 70%
# Salmoiraghi & Viganò: health_and_medical-optometrist & 70%
# Dan John Milano - C.C. Merlata Bloom: retail-clothing_store-men's_clothing_store & 70%
# Stefanel: retail-clothing_store & 70%
# BOSS Store: retail-clothing_store-men's_clothing_store & 50%
# Calvin Klein Jeans: retail-clothing_store & 70%
# Thun Shop Milano Merlata: retail-gift_shop & 50%
# Rinascimento: No predicted category
# Deposito Ferroviario di Milano Fiorenza: travel-trains & 50%
# Open Air Theatre San Carlo: arts_and_entertainment-theaters_and_performance_venues & 50%

# %%
# Assuming 'response' is the variable holding the LLM's output from the previous cell
# and response.text contains the string with predictions.

predicted_categories_string = "" # Initialize the string to store categories

if 'response' in locals() and hasattr(response, 'text'):
    llm_output_lines = response.text.split('\n')
    predicted_categories_only = []
    predicted_categories_list_for_string = [] # New list to build the string

    for line in llm_output_lines:
        if ':' in line:
            try:
                # Split by the first occurrence of ': ' to separate name from prediction
                parts = line.split(': ', 1)
                if len(parts) > 1:
                    prediction_part = parts[1].strip()
                    
                    # Remove potential surrounding quotes from the prediction part
                    if prediction_part.startswith("'") and prediction_part.endswith("'"):
                        prediction_part = prediction_part[1:-1]
                    
                    # Split the prediction part by ' & ' to separate category from confidence
                    category_confidence_split = prediction_part.split(' & ', 1)
                    category = category_confidence_split[0]
                    
                    # Further clean up if the category itself has quotes
                    if category.startswith("'") and category.endswith("'"):
                        category = category[1:-1]
                        
                    if category: # Modified condition
                        predicted_categories_only.append(category)
                        predicted_categories_list_for_string.append(category) # Add to new list
                        print(category)
            except Exception as e:
                print(f"Could not parse line: {line} - Error: {e}")
        elif line.strip(): # Handle cases where a line might just be a category
             # Further clean up if the category itself has quotes
            category = line.strip()
            if category.startswith("'") and category.endswith("'"):
                category = category[1:-1]
            if category: # Modified condition
                predicted_categories_only.append(category)
                predicted_categories_list_for_string.append(category) # Add to new list
                print(category)

    if not predicted_categories_only:
        print("No categories were extracted from the LLM response.")
    else:
        # Store categories in a newline-separated string
        predicted_categories_string = "\n".join(predicted_categories_list_for_string)
        print("\n--- Categories stored in string ---")
        print(predicted_categories_string)

else:
    print("LLM response object 'response' or 'response.text' not found.")

# The variable 'predicted_categories_string' now holds the desired string.
# You can print it to verify or use it for comparison later.
# print(f"\nFinal string for comparison:\n{predicted_categories_string}")
# Out:
# park
# No predicted category
# financial_service-money_transfer_services
# No predicted category
# No predicted category
# cultural_center
# medical_supply-dental_supply_store
# business_manufacturing_and_supply-plastic_manufacturer
# health_and_medical-physical_therapy
# attractions_and_activities-museum
# active_life-sports_and_fitness_instruction-fitness_trainer
# retail-arts_and_crafts-art_supply_store
# beauty_and_spa
# real_estate_agent
# sewing_and_alterations
# No predicted category
# real_estate_agent
# No predicted category
# education-driving_school
# health_and_medical-pharmacy
# retail-flowers_and_gifts_shop-florist
# financial_service-money_transfer_services
# retail-books_mags_music_and_video-bookstore
# eat_and_drink-pizza_restaurant
# active_life-yoga_studio
# beauty_and_spa-hair_salon
# No predicted category
# arts_and_entertainment-dance_club
# travel-transportation-metro_station
# active_life-sports_club_and_league
# education-music_school
# No predicted category
# it_service_and_computer_repair
# retail-home_and_garden-hardware_store
# automotive_services_and_repair-motorcycle_repair
# retail-leather_goods
# automotive-gas_station
# retail-supermarket
# retail-pet_store
# retail-pet_store
# automotive_dealer-car_dealer
# automotive_services_and_repair
# eat_and_drink-pizza_restaurant
# eat_and_drink-bar
# travel-bus_service
# automotive_dealer-motorcycle_dealer
# retail-shopping_center
# business_to_business
# travel-rental_service-car_rental_agency
# health_and_medical-counseling_and_mental_health-psychologist
# No predicted category
# automotive_services_and_repair
# No predicted category
# private_establishments_and_corporates-corporate_office
# automotive-automotive_repair
# business_equipment_and_supply
# business_equipment_and_supply
# home_service-movers
# retail-thrift_store
# retail-shoe_store
# No predicted category
# automotive-automotive_repair
# active_life-shooting_range
# home_service-movers
# business_to_business
# business_to_business-business_storage_and_transportation
# No predicted category
# No predicted category
# No predicted category
# travel-rental_service-car_rental_agency
# automotive-auto_body_shop
# education
# beauty_and_spa-hair_salon
# active_life-sports_and_recreation_venue-rock_climbing_gym
# home_service-contractor
# professional_services-advertising_agency
# automotive_services_and_repair-auto_glass_service
# business_advertising-business_signage
# No predicted category
# business_to_business-business_storage_and_transportation-freight_and_cargo_service
# No predicted category
# business_to_business-business_storage_and_transportation-freight_and_cargo_service
# business_to_business-business_storage_and_transportation-freight_and_cargo_service
# No predicted category
# active_life-sports_and_recreation_venue-gym
# No predicted category
# No predicted category
# No predicted category
# retail-shopping_center
# No predicted category
# automotive_parts_and_accessories
# professional_services-internet_marketing_service
# beauty_and_spa
# retail-beer_wine_and_spirits
# eat_and_drink-restaurant_equipment_and_supply
# eat_and_drink-cafe
# No predicted category
# retail-sporting_goods-bicycle_shop
# professional_services-public_relations
# No predicted category
# home_service-movers
# religious_organization-buddhist_temple
# retail-supermarket
# religious_organization-church_cathedral-catholic_church
# arts_and_entertainment-social_club
# arts_and_entertainment-social_club
# public_service_and_government-political_organization
# active_life-sports_club_and_league
# attractions_and_activities-zoo
# professional_services-cleaning_services
# retail-sporting_goods-ski_and_snowboard_shop
# No predicted category
# retail-home_and_garden-mattress_store
# eat_and_drink-bar
# eat_and_drink-restaurant
# eat_and_drink-restaurant
# automotive-automotive_services_and_repair-car_wash
# public_service_and_government-organization-social_service_organizations-charity_organization
# automotive-gas_station
# financial_service
# business_to_business
# eat_and_drink-doner_kebab
# No predicted category
# No predicted category
# No predicted category
# automotive_parts_and_accessories
# No predicted category
# retail-clothing_store
# automotive-gas_station
# retail
# retail-home_and_garden
# eat_and_drink-restaurant
# eat_and_drink-restaurant
# retail-furniture_store
# retail-home_improvement_store
# retail-home_improvement_store
# beauty_and_spa-hair_salon
# beauty_and_spa-hair_salon
# eat_and_drink-restaurant
# automotive_dealer-car_dealer
# No predicted category
# eat_and_drink-restaurant
# No predicted category
# business_to_business-business_storage_and_transportation-freight_and_cargo_service
# automotive-auto_body_shop
# automotive-auto_body_shop
# eat_and_drink-bar
# eat_and_drink-american_restaurant
# retail-home_and_garden
# eat_and_drink-pizza_restaurant
# retail-clothing_store-lingerie_store
# retail-clothing_store
# eat_and_drink-sandwich_shop
# retail-clothing_store
# eat_and_drink-burger_restaurant
# real_estate
# retail-shopping_center
# No predicted category
# No predicted category
# real_estate
# professional_services-laundry_services-laundromat
# No predicted category
# No predicted category
# eat_and_drink-restaurant
# retail-cards_and_stationery_store
# eat_and_drink-fast_food_restaurant
# travel-transportation-shipping_center
# retail-food-ice_cream_shop
# No predicted category
# professional_services
# No predicted category
# education-preschool
# public_service_and_government-organization-social_service_organizations
# public_service_and_government-community_center
# travel-transportation-taxi_service
# eat_and_drink-ice_cream_and_frozen_yoghurt-frozen_yoghurt_shop
# accommodation-holiday_rental_home
# No predicted category
# travel-transportation-shipping_center
# retail-electronics
# retail-video_game_store
# retail-mobile_phone_store
# retail-cosmetic_and_beauty_supplies
# retail-clothing_store
# automotive_dealer-car_dealer
# retail-food-butcher_shop
# eat_and_drink-poke_restaurant
# eat_and_drink-restaurant
# retail-jewelry_store
# electronics_repair_shop
# retail-books_mags_music_and_video-bookstore
# retail-clothing_store
# retail-cosmetic_and_beauty_supplies
# retail-cosmetic_and_beauty_supplies
# retail-clothing_store-lingerie_store
# retail-cosmetic_and_beauty_supplies
# No predicted category
# real_estate
# retail-home_and_garden-home_goods_store
# eat_and_drink-restaurant
# eat_and_drink-bistro
# retail-jewelry_store
# No predicted category
# retail-furniture_store
# retail-mobile_phone_store
# eat_and_drink-doner_kebab
# retail-food-desserts
# retail-appliance_store
# retail-clothing_store
# eat_and_drink-poke_restaurant
# eat_and_drink-german_restaurant
# retail-clothing_store-children's_clothing_store
# arts_and_entertainment-arcade
# attractions_and_activities-park
# retail-clothing_store
# retail-shoe_store
# retail-shopping_center
# retail-jewelry_store
# health_and_medical-optometrist
# eat_and_drink-burger_restaurant
# retail-clothing_store
# retail-jewelry_store
# retail-clothing_store
# beauty_and_spa-hair_salon
# retail-clothing_store
# eat_and_drink-american_restaurant
# beauty_and_spa-barber
# retail-clothing_store
# retail-cards_and_stationery_store
# retail-clothing_store-children's_clothing_store
# retail-sporting_goods
# eat_and_drink-asian_restaurant-japanese_restaurant
# retail-sporting_goods
# health_and_medical-optometrist
# retail-clothing_store-men's_clothing_store
# retail-clothing_store
# retail-clothing_store-men's_clothing_store
# retail-clothing_store
# retail-gift_shop
# No predicted category
# travel-trains
# arts_and_entertainment-theaters_and_performance_venues
#
# --- Categories stored in string ---
# park
# No predicted category
# financial_service-money_transfer_services
# No predicted category
# No predicted category
# cultural_center
# medical_supply-dental_supply_store
# business_manufacturing_and_supply-plastic_manufacturer
# health_and_medical-physical_therapy
# attractions_and_activities-museum
# active_life-sports_and_fitness_instruction-fitness_trainer
# retail-arts_and_crafts-art_supply_store
# beauty_and_spa
# real_estate_agent
# sewing_and_alterations
# No predicted category
# real_estate_agent
# No predicted category
# education-driving_school
# health_and_medical-pharmacy
# retail-flowers_and_gifts_shop-florist
# financial_service-money_transfer_services
# retail-books_mags_music_and_video-bookstore
# eat_and_drink-pizza_restaurant
# active_life-yoga_studio
# beauty_and_spa-hair_salon
# No predicted category
# arts_and_entertainment-dance_club
# travel-transportation-metro_station
# active_life-sports_club_and_league
# education-music_school
# No predicted category
# it_service_and_computer_repair
# retail-home_and_garden-hardware_store
# automotive_services_and_repair-motorcycle_repair
# retail-leather_goods
# automotive-gas_station
# retail-supermarket
# retail-pet_store
# retail-pet_store
# automotive_dealer-car_dealer
# automotive_services_and_repair
# eat_and_drink-pizza_restaurant
# eat_and_drink-bar
# travel-bus_service
# automotive_dealer-motorcycle_dealer
# retail-shopping_center
# business_to_business
# travel-rental_service-car_rental_agency
# health_and_medical-counseling_and_mental_health-psychologist
# No predicted category
# automotive_services_and_repair
# No predicted category
# private_establishments_and_corporates-corporate_office
# automotive-automotive_repair
# business_equipment_and_supply
# business_equipment_and_supply
# home_service-movers
# retail-thrift_store
# retail-shoe_store
# No predicted category
# automotive-automotive_repair
# active_life-shooting_range
# home_service-movers
# business_to_business
# business_to_business-business_storage_and_transportation
# No predicted category
# No predicted category
# No predicted category
# travel-rental_service-car_rental_agency
# automotive-auto_body_shop
# education
# beauty_and_spa-hair_salon
# active_life-sports_and_recreation_venue-rock_climbing_gym
# home_service-contractor
# professional_services-advertising_agency
# automotive_services_and_repair-auto_glass_service
# business_advertising-business_signage
# No predicted category
# business_to_business-business_storage_and_transportation-freight_and_cargo_service
# No predicted category
# business_to_business-business_storage_and_transportation-freight_and_cargo_service
# business_to_business-business_storage_and_transportation-freight_and_cargo_service
# No predicted category
# active_life-sports_and_recreation_venue-gym
# No predicted category
# No predicted category
# No predicted category
# retail-shopping_center
# No predicted category
# automotive_parts_and_accessories
# professional_services-internet_marketing_service
# beauty_and_spa
# retail-beer_wine_and_spirits
# eat_and_drink-restaurant_equipment_and_supply
# eat_and_drink-cafe
# No predicted category
# retail-sporting_goods-bicycle_shop
# professional_services-public_relations
# No predicted category
# home_service-movers
# religious_organization-buddhist_temple
# retail-supermarket
# religious_organization-church_cathedral-catholic_church
# arts_and_entertainment-social_club
# arts_and_entertainment-social_club
# public_service_and_government-political_organization
# active_life-sports_club_and_league
# attractions_and_activities-zoo
# professional_services-cleaning_services
# retail-sporting_goods-ski_and_snowboard_shop
# No predicted category
# retail-home_and_garden-mattress_store
# eat_and_drink-bar
# eat_and_drink-restaurant
# eat_and_drink-restaurant
# automotive-automotive_services_and_repair-car_wash
# public_service_and_government-organization-social_service_organizations-charity_organization
# automotive-gas_station
# financial_service
# business_to_business
# eat_and_drink-doner_kebab
# No predicted category
# No predicted category
# No predicted category
# automotive_parts_and_accessories
# No predicted category
# retail-clothing_store
# automotive-gas_station
# retail
# retail-home_and_garden
# eat_and_drink-restaurant
# eat_and_drink-restaurant
# retail-furniture_store
# retail-home_improvement_store
# retail-home_improvement_store
# beauty_and_spa-hair_salon
# beauty_and_spa-hair_salon
# eat_and_drink-restaurant
# automotive_dealer-car_dealer
# No predicted category
# eat_and_drink-restaurant
# No predicted category
# business_to_business-business_storage_and_transportation-freight_and_cargo_service
# automotive-auto_body_shop
# automotive-auto_body_shop
# eat_and_drink-bar
# eat_and_drink-american_restaurant
# retail-home_and_garden
# eat_and_drink-pizza_restaurant
# retail-clothing_store-lingerie_store
# retail-clothing_store
# eat_and_drink-sandwich_shop
# retail-clothing_store
# eat_and_drink-burger_restaurant
# real_estate
# retail-shopping_center
# No predicted category
# No predicted category
# real_estate
# professional_services-laundry_services-laundromat
# No predicted category
# No predicted category
# eat_and_drink-restaurant
# retail-cards_and_stationery_store
# eat_and_drink-fast_food_restaurant
# travel-transportation-shipping_center
# retail-food-ice_cream_shop
# No predicted category
# professional_services
# No predicted category
# education-preschool
# public_service_and_government-organization-social_service_organizations
# public_service_and_government-community_center
# travel-transportation-taxi_service
# eat_and_drink-ice_cream_and_frozen_yoghurt-frozen_yoghurt_shop
# accommodation-holiday_rental_home
# No predicted category
# travel-transportation-shipping_center
# retail-electronics
# retail-video_game_store
# retail-mobile_phone_store
# retail-cosmetic_and_beauty_supplies
# retail-clothing_store
# automotive_dealer-car_dealer
# retail-food-butcher_shop
# eat_and_drink-poke_restaurant
# eat_and_drink-restaurant
# retail-jewelry_store
# electronics_repair_shop
# retail-books_mags_music_and_video-bookstore
# retail-clothing_store
# retail-cosmetic_and_beauty_supplies
# retail-cosmetic_and_beauty_supplies
# retail-clothing_store-lingerie_store
# retail-cosmetic_and_beauty_supplies
# No predicted category
# real_estate
# retail-home_and_garden-home_goods_store
# eat_and_drink-restaurant
# eat_and_drink-bistro
# retail-jewelry_store
# No predicted category
# retail-furniture_store
# retail-mobile_phone_store
# eat_and_drink-doner_kebab
# retail-food-desserts
# retail-appliance_store
# retail-clothing_store
# eat_and_drink-poke_restaurant
# eat_and_drink-german_restaurant
# retail-clothing_store-children's_clothing_store
# arts_and_entertainment-arcade
# attractions_and_activities-park
# retail-clothing_store
# retail-shoe_store
# retail-shopping_center
# retail-jewelry_store
# health_and_medical-optometrist
# eat_and_drink-burger_restaurant
# retail-clothing_store
# retail-jewelry_store
# retail-clothing_store
# beauty_and_spa-hair_salon
# retail-clothing_store
# eat_and_drink-american_restaurant
# beauty_and_spa-barber
# retail-clothing_store
# retail-cards_and_stationery_store
# retail-clothing_store-children's_clothing_store
# retail-sporting_goods
# eat_and_drink-asian_restaurant-japanese_restaurant
# retail-sporting_goods
# health_and_medical-optometrist
# retail-clothing_store-men's_clothing_store
# retail-clothing_store
# retail-clothing_store-men's_clothing_store
# retail-clothing_store
# retail-gift_shop
# No predicted category
# travel-trains
# arts_and_entertainment-theaters_and_performance_venues

# %%
# Iterate through the place_dataset and print the POI name and its primary category
if 'place_dataset' in locals() and isinstance(place_dataset, pandas.DataFrame) and not place_dataset.empty:
    print("POI Name: Primary Category")
    print("---------------------------")
    for index, poi_row in place_dataset.iterrows():
        primary_name = "N/A"
        if 'names' in poi_row and poi_row['names'] and isinstance(poi_row['names'], dict) and 'primary' in poi_row['names']:
            primary_name = poi_row['names']['primary']
        
        primary_category = "N/A"
        if 'categories' in poi_row and poi_row['categories'] and isinstance(poi_row['categories'], dict) and 'primary' in poi_row['categories']:
            primary_category = poi_row['categories']['primary']
            
        print(f'"{primary_name}": "{primary_category}"')
else:
    print("place_dataset is not available or is empty.")
# Out:
# POI Name: Primary Category
# ---------------------------
# "Parco Nicolas": "park"
# "Edimol Sas": "newspaper_and_magazines_store"
# "Casual Store money transfer": "financial_service"
# "Molino Dorino": "bus_station"
# "Atlassib": "travel_services"
# "CSC - Casa salvadorena Cultural": "cultural_center"
# "Prodent Italia": "dentist"
# "Saldoplast": "plastic_fabrication_company"
# "Swiss DolorClast Italia": "advertising_agency"
# "Mud Museum - Open Space": "museum"
# "PR No Ordinary Training Studio": "life_coach"
# "Multiprint": "business_manufacturing_and_supply"
# "LR Health & Beauty Italia": "beauty_and_spa"
# "Team Russo": "real_estate_agent"
# "Malià": "sewing_and_alterations"
# "5Min S&S": "fashion"
# "Tempocasa Pero": "real_estate_service"
# "Pero": "grocery_store"
# "Autoscuola Pero S.a.s": "driving_school"
# "Farmacia Vittoria": "vitamins_and_supplements"
# "Eurogreen Fiori": "florist"
# "Western Union": "money_transfer_services"
# "Libri e Giardini": "holiday_rental_home"
# "Pizzeria Sempione Da Lorenzo E Ivan | Pero": "pizza_restaurant"
# "Easyoga & Fun": "amateur_sports_team"
# "Laurita Michele": "beauty_salon"
# "Magistroni Alessio": "shopping"
# "Puro Tango": "topic_concert_venue"
# "Pero (metropolitana di Milano)": "transportation"
# "FCW Wrestling": "active_life"
# "Scuola di musica giorgio canali 3": "music_school"
# "Rising Sun Wrestling Promotion": "active_life"
# "Matrix Informatica Srl": "computer_store"
# "Ferramenta Allegri": "hardware_store"
# "SOS Monopattini Elettrici": "machine_shop"
# "ugly.milano": "clothing_store"
# "Eni Station": "gas_station"
# "Penny": "discount_store"
# "Arcaplanet": "pet_store"
# "Maxi Zoo Italia": "pet_services"
# "Blustar Car": "car_dealer"
# "Mercedes-Benz Service": "car_dealer"
# "Pizza e Brace": "restaurant"
# "Milly bar": "bar"
# "Autostradale": "airport_shuttles"
# "X-Moto": "motorcycle_dealer"
# "MABA Shopping Pero": "outlet_store"
# "Safetykleen Italia - Soluzioni complete per il lavaggio pezzi": "professional_services"
# "Morini Rent Milano Fiera - Pero - Noleggio Auto e Furgoni": "rental_services"
# "Dott.ssa Simona Adelaide Martini Psicologa-Psicoterapeuta Emdr": "psychologist"
# "Matcro Lab di Dott. Mattia Crosta": "health_and_medical"
# "REB- Riparazioni contachilometri Milano": "engine_repair_service"
# "Speedy Car Snc": "automotive_repair"
# "Cogepro Business Center": "event_planning"
# "Motormobile Rovida": "automotive_repair"
# "Villamark Marcatura - Villa Luigi & Figlio Srl": "professional_services"
# "VILLA L. & FIGLIO srl - Macchine Laser e Timbri": "office_equipment"
# "Bolliger - Traslochi Internazionali e Relocation": "truck_dealer_for_businesses"
# "Usatokay - Mercatino dell'Usato": "flea_market"
# "Timberland": "clothing_store"
# "DACAN": "dance_club"
# "Morini Rent Milano Fiera - Pero - Noleggio Auto e Furgoni": "rental_services"
# "Gramsci Car Center S.r.l": "automotive_repair"
# "Action Shooting Italia": "shooting_range"
# "Bolliger Moving": "storage_facility"
# "Gerol Srl": "industrial_equipment"
# "Easy&Fast": "professional_services"
# "Santoemma Srl": "industrial_company"
# "Metal Tech": "metal_fabricator"
# "Termostahl srl - tempra per induzione": "industrial_company"
# "Hertz Autonoleggio - Milan,pero - Bricoman HLE": "travel"
# "G.T.R. Car Service": "automotive_repair"
# "Deltacon Ricerca e Sviluppo": "b2b_science_and_technology"
# "Evoluzione Parrucchieri": "beauty_salon"
# "Urban Wall - Milano Climbing Factory": "rock_climbing_spot"
# "Impresa Montali srl": "fire_protection_service"
# "SGS Comunicazione": "advertising_agency"
# "VetroCar": "auto_glass_service"
# "Milano Sign": "marketing_agency"
# "Route 41": "music_venue"
# "DSS Trasporti Bio Pharma Solution": "transportation"
# "Flavourland srl": "grocery_store"
# "Dss Bio Pharma Solution Trasporti": "truck_dealer_for_businesses"
# "Dss Bio-Pharma": "truck_dealer_for_businesses"
# "Bellinzoni SRL": "candle_store"
# "The Loft Milano Villapizzone": "gym"
# "StoryTime - Lombardia": "broadcasting_media_production"
# "Rhiag Group": "automotive_parts_and_accessories"
# "Vimercati S.p.A.": "vehicle_shipping"
# "Consorzio Insiamo": "professional_services"
# "The Gate": "escape_rooms"
# "Europatarghe srl": "shopping"
# "Matiba digital marketing": "media_news_company"
# "Detente et Beaute": "beauty_and_spa"
# "Distilleria Artigianale Milano": "distillery"
# "SAMA di Massimo Santacaterina": "wholesale_store"
# "Bar Bijou Caffetteria": "bar"
# "Presspoint": "printing_services"
# "Saltafoss": "bicycle_shop"
# "Reputation Manager S.p.A. - Ingegneria Reputazionale": "marketing_consultant"
# "Payer": "business_signage"
# "Dubini Traslochi E Servizi Srl": "storage_facility"
# "Mahamevnawa Buddhist Meditation Monastery": "meditation_center"
# "Esselunga": "supermarket"
# "Parrocchia San Leonardo": "church_cathedral"
# "Gruppo Sirio": "community_services_non_profits"
# "Circolo Fotografico Trevisani": "social_service_organizations"
# "Circolo SEL - E. Ragionieri": "public_service_and_government"
# "ASD Zonaotto": "active_life"
# "Balzoo - Banco Italiano Zoologico APS": "community_services_non_profits"
# "Faridamore": "home_cleaning"
# "Skilifting & Bike": "sporting_goods"
# "Leone": "gas_station"
# "Mandelli materassi": "bedding_and_bath_stores"
# "Bar fratelli Guido": "fast_food_restaurant"
# "La Pergola": "restaurant"
# "Trattoria Italo Cinese": "chinese_restaurant"
# "Autolavaggio SM2": "car_wash"
# "Joe Eze Foundation": "non_governmental_association"
# "Esso Milano Via Gallarate": "home_goods_store"
# "SisalPay": "financial_service"
# "Bardelli Taglio Laser": "tattoo_and_piercing"
# "Kebap House": "doner_kebab"
# "Vita Studio": "event_photography"
# "Vetrofanie Milano sas di Pulici Paolo": "business_advertising"
# "Strane Officine": "music_venue"
# "Non Solo Cross": "motorcycle_dealer"
# "Autoclub S.N.C.": "automotive_repair"
# "Lucia Pascale eco designer": "fashion"
# "Mas Metano": "car_wash"
# "ODStore": "candy_store"
# "Gruppo Grancasa": "furniture_store"
# "Ristorante La Rosa Incantata": "restaurant"
# "La Rosa incantata": "restaurant"
# "Grancasa": "appliance_store"
# "Tecnomat": "building_supply_store"
# "Bricoman": "men's_clothing_store"
# "MAGIA Coiffeur by Lella": "beauty_and_spa"
# "Coiffeur Pour Dame Di Attanasio Graziella": "hair_salon"
# "Restaurant One": "sushi_restaurant"
# "Merbag S.p.a.": "home_goods_store"
# "Due Bacchette": "sushi_restaurant"
# "Cinque Stelle": "restaurant"
# "TESL": "surgical_appliances_and_supplies"
# "Mercedes-Benz Service": "car_dealer"
# "Tecnomat": "building_supply_store"
# "Gazzotti Spa": "truck_dealer_for_businesses"
# "Carrozzeria La Moderna": "auto_body_shop"
# "La Moderna s.r.l": "automotive_repair"
# "Bar Atlantic": "beverage_store"
# "Hamerica’s Cascina merlata bloom ": "american_restaurant"
# "Excélsa Italia": "home_goods_store"
# "Rossopomodoro Cascina Merlata": "pizza_restaurant"
# "Intimissimi": "children's_clothing_store"
# "Tezenis": "children's_clothing_store"
# "Panino Giusto": "cafe"
# "Calzedonia": "children's_clothing_store"
# "Bun Burgers - Merlata Bloom": "fast_food_restaurant"
# "Corte Futura": "real_estate"
# "Al Merlata Bloom Mall - lo Shopping Center di Milano": "shopping"
# "Triumph of Dreams": "counseling_and_mental_health"
# "Cascina Merlata": "hiking_trail"
# "Citta Contemporanea": "real_estate"
# "Lavanderia Fresco & Pulito": "dry_cleaning"
# "Premium Service": "professional_services"
# "Piazza Giovanni Pesce": "public_plaza"
# "Mare culturale urbano food hub": "pizza_restaurant"
# "La Graffetta In Cascina": "toy_store"
# "Cascina Merlata": "landmark_and_historical_building"
# "Merlata Map Food": "fast_food_restaurant"
# "DHL Service Point (CARTOLERIA LA GRAFFETTA)": "courier_and_delivery_services"
# "Gelateria Baci Sottozero": "ice_cream_shop"
# "UpTown Milano": "landmark_and_historical_building"
# "Cascina Merlata": "attractions_and_activities"
# "Studio MErlaTA": "psychotherapist"
# "Family Hub - Il portale delle  opportunità": "professional_services"
# "Bebek Nido e Scuola dell’Infanzia Bilingue": "school"
# "Spaziopensiero Onlus": "community_services_non_profits"
# "Cascina Merlata- Community Center": "home_developer"
# "NCC Milano Atlas": "limo_services"
# "La Yogurteria CC Merlata Bloom": "hair_stylist"
# "InternoChicMilano CIN IT015146C2TGYDD39G": "holiday_rental_home"
# "Urso Impianti S.R.L.": "machine_shop"
# "BRT Express Courier": "shipping_center"
# "Bruno Euronics - Milano": "electronics"
# "GameStop": "video_game_store"
# "Phonelab - C.C. Merlata Bloom": "mobile_phone_store"
# "Erbolario Merlata Bloom": "beauty_and_spa"
# "Champion Store": "sports_wear"
# "Merbag Italia": "car_dealer"
# "Il Mannarino": "butcher_shop"
# "Poke House - Cascina Merlata": "restaurant"
# "Signorvino Milano - Cascina Merlata": "restaurant"
# "STROILI": "children's_clothing_store"
# "Juice Milano Merlata | Apple Premium Partner e Centro Assistenza Autorizzato Apple": "computer_store"
# "Mondadori Bookstore": "bookstore"
# "Mango": "clothing_store"
# "Yves Rocher": "retail"
# "Nashi Store Merlata Bloom": "hair_supply_stores"
# "Intimissimi Uomo": "women's_clothing_store"
# "Kiko Milano": "retail"
# "Inside-Out": "business_advertising"
# "Q.re Cascina Merlata - Milano": "landmark_and_historical_building"
# "Kasanova": "children's_clothing_store"
# "Pirates Bay - Milano Merlata Bloom": "restaurant"
# "Caruso Caffe e Bistrot": "bar"
# "Gioielleria Stroili": "jewelry_store"
# "Calliope": "children's_clothing_store"
# "IKEA Milano Cascina Merlata plan and order point": "furniture_store"
# "Vodafone Store": "mobile_phone_store"
# "Kebhouze - Merlata Bloom": "chicken_restaurant"
# "Signorvino Milano - Cascina Merlata": "italian_restaurant"
# "Cioccolatitaliani - Merlata Bloom Milano": "ice_cream_and_frozen_yoghurt"
# "Vorwerk Point Bimby Folletto": "appliance_store"
# "Gutteridge": "children's_clothing_store"
# "Macha Pokè Merlata": "poke"
# "Löwengrube Merlata Bloom Milano": "german_restaurant"
# "Mayoral - Negozio di Abbigliamento per bambini e neonati": "children's_clothing_store"
# "LOG Lot Of Games - Merlata Bloom": "arts_and_entertainment"
# "Parco pubblico Cascina Merlata": "park"
# "JACK & JONES": "men's_clothing_store"
# "Primadonna Collection": "clothing_store"
# "Merlata Bloom Milano": "real_estate"
# "Kaidor Gioiellerie": "jewelry_store"
# "Ottica GrandVision Centro Commerciale Merlata Bloom Milano": "retail"
# "Neat Burger": "vegetarian_restaurant"
# "dixie": "children's_clothing_store"
# "Marlù Store Milano C.C Merlata Bloom": "jewelry_store"
# "GUESS": "clothing_store"
# "Jean Louis David Parrucchieri CC Merlata Bloom": "hair_salon"
# "MOTIVI": "children's_clothing_store"
# "Old Wild West - Milano C.C. Merlata Bloom": "gift_shop"
# "Tezenis": "clothing_store"
# "Calzedonia": "children's_clothing_store"
# "The Barber&Co CC Merlata Bloom": "barber"
# "IMPERIAL": "children's_clothing_store"
# "Boutique Legami": "children's_clothing_store"
# "OKAIDI": "children's_clothing_store"
# "Decathlon Milano Merlata": "kids_recreation_and_party"
# "Ramen Bar Akira": "japanese_restaurant"
# "JD Sports": "sports_wear"
# "Poke House - Cascina Merlata": "bar"
# "Salmoiraghi & Viganò": "eyewear_and_optician"
# "Dan John Milano - C.C. Merlata Bloom": "men's_clothing_store"
# "Stefanel": "clothing_store"
# "BOSS Store": "clothing_store"
# "Calvin Klein Jeans": "clothing_store"
# "Thun Shop Milano Merlata": "flowers_and_gifts_shop"
# "Rinascimento": "children's_clothing_store"
# "Deposito Ferroviario di Milano Fiorenza": "transportation"
# "Open Air Theatre San Carlo": "theatre"

# %%
# Initialize an empty list to store primary categories
primary_categories_list = []

if 'place_dataset' in locals() and isinstance(place_dataset, pandas.DataFrame) and not place_dataset.empty:
    for index, poi_row in place_dataset.iterrows():
        primary_category = "N/A"
        if 'categories' in poi_row and poi_row['categories'] and isinstance(poi_row['categories'], dict) and 'primary' in poi_row['categories']:
            primary_category = poi_row['categories']['primary']
        primary_categories_list.append(primary_category)
    
    # Join the list into a newline-separated string
    primary_categories_string = "\n".join(primary_categories_list)
    print(primary_categories_string)
else:
    primary_categories_string = "" # Initialize as empty if dataset is not valid
    print("place_dataset is not available, not a DataFrame, or is empty. No categories stored.")

# The variable 'primary_categories_string' now holds the desired string.
# You can print it to verify or use it for comparison later.
# print(f"\nFinal string for comparison:\n{primary_categories_string}")
# Out:
# park
# newspaper_and_magazines_store
# financial_service
# bus_station
# travel_services
# cultural_center
# dentist
# plastic_fabrication_company
# advertising_agency
# museum
# life_coach
# business_manufacturing_and_supply
# beauty_and_spa
# real_estate_agent
# sewing_and_alterations
# fashion
# real_estate_service
# grocery_store
# driving_school
# vitamins_and_supplements
# florist
# money_transfer_services
# holiday_rental_home
# pizza_restaurant
# amateur_sports_team
# beauty_salon
# shopping
# topic_concert_venue
# transportation
# active_life
# music_school
# active_life
# computer_store
# hardware_store
# machine_shop
# clothing_store
# gas_station
# discount_store
# pet_store
# pet_services
# car_dealer
# car_dealer
# restaurant
# bar
# airport_shuttles
# motorcycle_dealer
# outlet_store
# professional_services
# rental_services
# psychologist
# health_and_medical
# engine_repair_service
# automotive_repair
# event_planning
# automotive_repair
# professional_services
# office_equipment
# truck_dealer_for_businesses
# flea_market
# clothing_store
# dance_club
# rental_services
# automotive_repair
# shooting_range
# storage_facility
# industrial_equipment
# professional_services
# industrial_company
# metal_fabricator
# industrial_company
# travel
# automotive_repair
# b2b_science_and_technology
# beauty_salon
# rock_climbing_spot
# fire_protection_service
# advertising_agency
# auto_glass_service
# marketing_agency
# music_venue
# transportation
# grocery_store
# truck_dealer_for_businesses
# truck_dealer_for_businesses
# candle_store
# gym
# broadcasting_media_production
# automotive_parts_and_accessories
# vehicle_shipping
# professional_services
# escape_rooms
# shopping
# media_news_company
# beauty_and_spa
# distillery
# wholesale_store
# bar
# printing_services
# bicycle_shop
# marketing_consultant
# business_signage
# storage_facility
# meditation_center
# supermarket
# church_cathedral
# community_services_non_profits
# social_service_organizations
# public_service_and_government
# active_life
# community_services_non_profits
# home_cleaning
# sporting_goods
# gas_station
# bedding_and_bath_stores
# fast_food_restaurant
# restaurant
# chinese_restaurant
# car_wash
# non_governmental_association
# home_goods_store
# financial_service
# tattoo_and_piercing
# doner_kebab
# event_photography
# business_advertising
# music_venue
# motorcycle_dealer
# automotive_repair
# fashion
# car_wash
# candy_store
# furniture_store
# restaurant
# restaurant
# appliance_store
# building_supply_store
# men's_clothing_store
# beauty_and_spa
# hair_salon
# sushi_restaurant
# home_goods_store
# sushi_restaurant
# restaurant
# surgical_appliances_and_supplies
# car_dealer
# building_supply_store
# truck_dealer_for_businesses
# auto_body_shop
# automotive_repair
# beverage_store
# american_restaurant
# home_goods_store
# pizza_restaurant
# children's_clothing_store
# children's_clothing_store
# cafe
# children's_clothing_store
# fast_food_restaurant
# real_estate
# shopping
# counseling_and_mental_health
# hiking_trail
# real_estate
# dry_cleaning
# professional_services
# public_plaza
# pizza_restaurant
# toy_store
# landmark_and_historical_building
# fast_food_restaurant
# courier_and_delivery_services
# ice_cream_shop
# landmark_and_historical_building
# attractions_and_activities
# psychotherapist
# professional_services
# school
# community_services_non_profits
# home_developer
# limo_services
# hair_stylist
# holiday_rental_home
# machine_shop
# shipping_center
# electronics
# video_game_store
# mobile_phone_store
# beauty_and_spa
# sports_wear
# car_dealer
# butcher_shop
# restaurant
# restaurant
# children's_clothing_store
# computer_store
# bookstore
# clothing_store
# retail
# hair_supply_stores
# women's_clothing_store
# retail
# business_advertising
# landmark_and_historical_building
# children's_clothing_store
# restaurant
# bar
# jewelry_store
# children's_clothing_store
# furniture_store
# mobile_phone_store
# chicken_restaurant
# italian_restaurant
# ice_cream_and_frozen_yoghurt
# appliance_store
# children's_clothing_store
# poke
# german_restaurant
# children's_clothing_store
# arts_and_entertainment
# park
# men's_clothing_store
# clothing_store
# real_estate
# jewelry_store
# retail
# vegetarian_restaurant
# children's_clothing_store
# jewelry_store
# clothing_store
# hair_salon
# children's_clothing_store
# gift_shop
# clothing_store
# children's_clothing_store
# barber
# children's_clothing_store
# children's_clothing_store
# children's_clothing_store
# kids_recreation_and_party
# japanese_restaurant
# sports_wear
# bar
# eyewear_and_optician
# men's_clothing_store
# clothing_store
# clothing_store
# clothing_store
# flowers_and_gifts_shop
# children's_clothing_store
# transportation
# theatre

# %%
# Ensure both strings are available
if 'primary_categories_string' in locals() and 'predicted_categories_string' in locals() \
    and isinstance(primary_categories_string, str) and isinstance(predicted_categories_string, str):

     primary_list = primary_categories_string.strip().split('\n')
     predicted_list = predicted_categories_string.strip().split('\n')

     # Remove any empty strings that might result from splitting if there are trailing newlines
     primary_list = [cat for cat in primary_list if cat]
     predicted_list = [cat for cat in predicted_list if cat]
     
     similar_count = 0
     total_compared = 0
     unmatched_llm_pois = [] # To store LLM predictions that didn't match
     unmatched_for_review = [] # To store (original, predicted) pairs for mismatches

     # Determine the number of comparisons to make (the shorter of the two lists)
     # This is important if the LLM didn't provide a prediction for every POI
     num_comparisons = min(len(primary_list), len(predicted_list))

     print(f"Comparing {num_comparisons} pairs of categories.")
     print("--- Comparison Results ---")
     print("Original Category  | Predicted Category | Match?")
     print("-------------------|--------------------|--------")

     for i in range(num_comparisons):
          original_cat = primary_list[i].strip()
          predicted_cat = predicted_list[i].strip()
          total_compared += 1
          
          match_status = "No"
          if original_cat == predicted_cat:
                similar_count += 1
                match_status = "Yes"
          else:
                # Store mismatches for review
                unmatched_for_review.append({'original': original_cat, 'predicted': predicted_cat, 'index_in_list': i})
                
          print(f"{original_cat:<20}| {predicted_cat:<20}| {match_status}")

     print(f"\nNumber of matching categories: {similar_count}")
     print(f"Total categories compared: {total_compared}")

     if total_compared > 0:
          accuracy = (similar_count / total_compared) * 100
          print(f"Accuracy: {accuracy:.2f}%")
     else:
          print("No categories were compared.")

     # Report if lists had different lengths
     if len(primary_list) != len(predicted_list):
          print(f"\nWarning: Original categories list had {len(primary_list)} entries, "
                  f"while predicted categories list had {len(predicted_list)} entries. "
                  f"Comparison was done for the first {num_comparisons} entries.")

     # Print details of mismatches for review
    #  if unmatched_for_review:
    #       print("\n--- Mismatched Categories for Review ---")
    #       for item in unmatched_for_review:
    #             print(f"Index: {item['index_in_list']}, Original: '{item['original']}', Predicted: '{item['predicted']}'")
    #  else:
    #       if total_compared > 0:
    #             print("\nAll compared categories matched!")

else:
     print("Error: 'primary_categories_string' or 'predicted_categories_string' not found or not a string.")
     print("Please ensure the previous cells have been executed correctly.")
# Out:
# Comparing 242 pairs of categories.
# --- Comparison Results ---
# Original Category  | Predicted Category | Match?
# -------------------|--------------------|--------
# park                | park                | Yes
# newspaper_and_magazines_store| No predicted category| No
# financial_service   | financial_service-money_transfer_services| No
# bus_station         | No predicted category| No
# travel_services     | No predicted category| No
# cultural_center     | cultural_center     | Yes
# dentist             | medical_supply-dental_supply_store| No
# plastic_fabrication_company| business_manufacturing_and_supply-plastic_manufacturer| No
# advertising_agency  | health_and_medical-physical_therapy| No
# museum              | attractions_and_activities-museum| No
# life_coach          | active_life-sports_and_fitness_instruction-fitness_trainer| No
# business_manufacturing_and_supply| retail-arts_and_crafts-art_supply_store| No
# beauty_and_spa      | beauty_and_spa      | Yes
# real_estate_agent   | real_estate_agent   | Yes
# sewing_and_alterations| sewing_and_alterations| Yes
# fashion             | No predicted category| No
# real_estate_service | real_estate_agent   | No
# grocery_store       | No predicted category| No
# driving_school      | education-driving_school| No
# vitamins_and_supplements| health_and_medical-pharmacy| No
# florist             | retail-flowers_and_gifts_shop-florist| No
# money_transfer_services| financial_service-money_transfer_services| No
# holiday_rental_home | retail-books_mags_music_and_video-bookstore| No
# pizza_restaurant    | eat_and_drink-pizza_restaurant| No
# amateur_sports_team | active_life-yoga_studio| No
# beauty_salon        | beauty_and_spa-hair_salon| No
# shopping            | No predicted category| No
# topic_concert_venue | arts_and_entertainment-dance_club| No
# transportation      | travel-transportation-metro_station| No
# active_life         | active_life-sports_club_and_league| No
# music_school        | education-music_school| No
# active_life         | No predicted category| No
# computer_store      | it_service_and_computer_repair| No
# hardware_store      | retail-home_and_garden-hardware_store| No
# machine_shop        | automotive_services_and_repair-motorcycle_repair| No
# clothing_store      | retail-leather_goods| No
# gas_station         | automotive-gas_station| No
# discount_store      | retail-supermarket  | No
# pet_store           | retail-pet_store    | No
# pet_services        | retail-pet_store    | No
# car_dealer          | automotive_dealer-car_dealer| No
# car_dealer          | automotive_services_and_repair| No
# restaurant          | eat_and_drink-pizza_restaurant| No
# bar                 | eat_and_drink-bar   | No
# airport_shuttles    | travel-bus_service  | No
# motorcycle_dealer   | automotive_dealer-motorcycle_dealer| No
# outlet_store        | retail-shopping_center| No
# professional_services| business_to_business| No
# rental_services     | travel-rental_service-car_rental_agency| No
# psychologist        | health_and_medical-counseling_and_mental_health-psychologist| No
# health_and_medical  | No predicted category| No
# engine_repair_service| automotive_services_and_repair| No
# automotive_repair   | No predicted category| No
# event_planning      | private_establishments_and_corporates-corporate_office| No
# automotive_repair   | automotive-automotive_repair| No
# professional_services| business_equipment_and_supply| No
# office_equipment    | business_equipment_and_supply| No
# truck_dealer_for_businesses| home_service-movers | No
# flea_market         | retail-thrift_store | No
# clothing_store      | retail-shoe_store   | No
# dance_club          | No predicted category| No
# rental_services     | automotive-automotive_repair| No
# automotive_repair   | active_life-shooting_range| No
# shooting_range      | home_service-movers | No
# storage_facility    | business_to_business| No
# industrial_equipment| business_to_business-business_storage_and_transportation| No
# professional_services| No predicted category| No
# industrial_company  | No predicted category| No
# metal_fabricator    | No predicted category| No
# industrial_company  | travel-rental_service-car_rental_agency| No
# travel              | automotive-auto_body_shop| No
# automotive_repair   | education           | No
# b2b_science_and_technology| beauty_and_spa-hair_salon| No
# beauty_salon        | active_life-sports_and_recreation_venue-rock_climbing_gym| No
# rock_climbing_spot  | home_service-contractor| No
# fire_protection_service| professional_services-advertising_agency| No
# advertising_agency  | automotive_services_and_repair-auto_glass_service| No
# auto_glass_service  | business_advertising-business_signage| No
# marketing_agency    | No predicted category| No
# music_venue         | business_to_business-business_storage_and_transportation-freight_and_cargo_service| No
# transportation      | No predicted category| No
# grocery_store       | business_to_business-business_storage_and_transportation-freight_and_cargo_service| No
# truck_dealer_for_businesses| business_to_business-business_storage_and_transportation-freight_and_cargo_service| No
# truck_dealer_for_businesses| No predicted category| No
# candle_store        | active_life-sports_and_recreation_venue-gym| No
# gym                 | No predicted category| No
# broadcasting_media_production| No predicted category| No
# automotive_parts_and_accessories| No predicted category| No
# vehicle_shipping    | retail-shopping_center| No
# professional_services| No predicted category| No
# escape_rooms        | automotive_parts_and_accessories| No
# shopping            | professional_services-internet_marketing_service| No
# media_news_company  | beauty_and_spa      | No
# beauty_and_spa      | retail-beer_wine_and_spirits| No
# distillery          | eat_and_drink-restaurant_equipment_and_supply| No
# wholesale_store     | eat_and_drink-cafe  | No
# bar                 | No predicted category| No
# printing_services   | retail-sporting_goods-bicycle_shop| No
# bicycle_shop        | professional_services-public_relations| No
# marketing_consultant| No predicted category| No
# business_signage    | home_service-movers | No
# storage_facility    | religious_organization-buddhist_temple| No
# meditation_center   | retail-supermarket  | No
# supermarket         | religious_organization-church_cathedral-catholic_church| No
# church_cathedral    | arts_and_entertainment-social_club| No
# community_services_non_profits| arts_and_entertainment-social_club| No
# social_service_organizations| public_service_and_government-political_organization| No
# public_service_and_government| active_life-sports_club_and_league| No
# active_life         | attractions_and_activities-zoo| No
# community_services_non_profits| professional_services-cleaning_services| No
# home_cleaning       | retail-sporting_goods-ski_and_snowboard_shop| No
# sporting_goods      | No predicted category| No
# gas_station         | retail-home_and_garden-mattress_store| No
# bedding_and_bath_stores| eat_and_drink-bar   | No
# fast_food_restaurant| eat_and_drink-restaurant| No
# restaurant          | eat_and_drink-restaurant| No
# chinese_restaurant  | automotive-automotive_services_and_repair-car_wash| No
# car_wash            | public_service_and_government-organization-social_service_organizations-charity_organization| No
# non_governmental_association| automotive-gas_station| No
# home_goods_store    | financial_service   | No
# financial_service   | business_to_business| No
# tattoo_and_piercing | eat_and_drink-doner_kebab| No
# doner_kebab         | No predicted category| No
# event_photography   | No predicted category| No
# business_advertising| No predicted category| No
# music_venue         | automotive_parts_and_accessories| No
# motorcycle_dealer   | No predicted category| No
# automotive_repair   | retail-clothing_store| No
# fashion             | automotive-gas_station| No
# car_wash            | retail              | No
# candy_store         | retail-home_and_garden| No
# furniture_store     | eat_and_drink-restaurant| No
# restaurant          | eat_and_drink-restaurant| No
# restaurant          | retail-furniture_store| No
# appliance_store     | retail-home_improvement_store| No
# building_supply_store| retail-home_improvement_store| No
# men's_clothing_store| beauty_and_spa-hair_salon| No
# beauty_and_spa      | beauty_and_spa-hair_salon| No
# hair_salon          | eat_and_drink-restaurant| No
# sushi_restaurant    | automotive_dealer-car_dealer| No
# home_goods_store    | No predicted category| No
# sushi_restaurant    | eat_and_drink-restaurant| No
# restaurant          | No predicted category| No
# surgical_appliances_and_supplies| business_to_business-business_storage_and_transportation-freight_and_cargo_service| No
# car_dealer          | automotive-auto_body_shop| No
# building_supply_store| automotive-auto_body_shop| No
# truck_dealer_for_businesses| eat_and_drink-bar   | No
# auto_body_shop      | eat_and_drink-american_restaurant| No
# automotive_repair   | retail-home_and_garden| No
# beverage_store      | eat_and_drink-pizza_restaurant| No
# american_restaurant | retail-clothing_store-lingerie_store| No
# home_goods_store    | retail-clothing_store| No
# pizza_restaurant    | eat_and_drink-sandwich_shop| No
# children's_clothing_store| retail-clothing_store| No
# children's_clothing_store| eat_and_drink-burger_restaurant| No
# cafe                | real_estate         | No
# children's_clothing_store| retail-shopping_center| No
# fast_food_restaurant| No predicted category| No
# real_estate         | No predicted category| No
# shopping            | real_estate         | No
# counseling_and_mental_health| professional_services-laundry_services-laundromat| No
# hiking_trail        | No predicted category| No
# real_estate         | No predicted category| No
# dry_cleaning        | eat_and_drink-restaurant| No
# professional_services| retail-cards_and_stationery_store| No
# public_plaza        | eat_and_drink-fast_food_restaurant| No
# pizza_restaurant    | travel-transportation-shipping_center| No
# toy_store           | retail-food-ice_cream_shop| No
# landmark_and_historical_building| No predicted category| No
# fast_food_restaurant| professional_services| No
# courier_and_delivery_services| No predicted category| No
# ice_cream_shop      | education-preschool | No
# landmark_and_historical_building| public_service_and_government-organization-social_service_organizations| No
# attractions_and_activities| public_service_and_government-community_center| No
# psychotherapist     | travel-transportation-taxi_service| No
# professional_services| eat_and_drink-ice_cream_and_frozen_yoghurt-frozen_yoghurt_shop| No
# school              | accommodation-holiday_rental_home| No
# community_services_non_profits| No predicted category| No
# home_developer      | travel-transportation-shipping_center| No
# limo_services       | retail-electronics  | No
# hair_stylist        | retail-video_game_store| No
# holiday_rental_home | retail-mobile_phone_store| No
# machine_shop        | retail-cosmetic_and_beauty_supplies| No
# shipping_center     | retail-clothing_store| No
# electronics         | automotive_dealer-car_dealer| No
# video_game_store    | retail-food-butcher_shop| No
# mobile_phone_store  | eat_and_drink-poke_restaurant| No
# beauty_and_spa      | eat_and_drink-restaurant| No
# sports_wear         | retail-jewelry_store| No
# car_dealer          | electronics_repair_shop| No
# butcher_shop        | retail-books_mags_music_and_video-bookstore| No
# restaurant          | retail-clothing_store| No
# restaurant          | retail-cosmetic_and_beauty_supplies| No
# children's_clothing_store| retail-cosmetic_and_beauty_supplies| No
# computer_store      | retail-clothing_store-lingerie_store| No
# bookstore           | retail-cosmetic_and_beauty_supplies| No
# clothing_store      | No predicted category| No
# retail              | real_estate         | No
# hair_supply_stores  | retail-home_and_garden-home_goods_store| No
# women's_clothing_store| eat_and_drink-restaurant| No
# retail              | eat_and_drink-bistro| No
# business_advertising| retail-jewelry_store| No
# landmark_and_historical_building| No predicted category| No
# children's_clothing_store| retail-furniture_store| No
# restaurant          | retail-mobile_phone_store| No
# bar                 | eat_and_drink-doner_kebab| No
# jewelry_store       | retail-food-desserts| No
# children's_clothing_store| retail-appliance_store| No
# furniture_store     | retail-clothing_store| No
# mobile_phone_store  | eat_and_drink-poke_restaurant| No
# chicken_restaurant  | eat_and_drink-german_restaurant| No
# italian_restaurant  | retail-clothing_store-children's_clothing_store| No
# ice_cream_and_frozen_yoghurt| arts_and_entertainment-arcade| No
# appliance_store     | attractions_and_activities-park| No
# children's_clothing_store| retail-clothing_store| No
# poke                | retail-shoe_store   | No
# german_restaurant   | retail-shopping_center| No
# children's_clothing_store| retail-jewelry_store| No
# arts_and_entertainment| health_and_medical-optometrist| No
# park                | eat_and_drink-burger_restaurant| No
# men's_clothing_store| retail-clothing_store| No
# clothing_store      | retail-jewelry_store| No
# real_estate         | retail-clothing_store| No
# jewelry_store       | beauty_and_spa-hair_salon| No
# retail              | retail-clothing_store| No
# vegetarian_restaurant| eat_and_drink-american_restaurant| No
# children's_clothing_store| beauty_and_spa-barber| No
# jewelry_store       | retail-clothing_store| No
# clothing_store      | retail-cards_and_stationery_store| No
# hair_salon          | retail-clothing_store-children's_clothing_store| No
# children's_clothing_store| retail-sporting_goods| No
# gift_shop           | eat_and_drink-asian_restaurant-japanese_restaurant| No
# clothing_store      | retail-sporting_goods| No
# children's_clothing_store| health_and_medical-optometrist| No
# barber              | retail-clothing_store-men's_clothing_store| No
# children's_clothing_store| retail-clothing_store| No
# children's_clothing_store| retail-clothing_store-men's_clothing_store| No
# children's_clothing_store| retail-clothing_store| No
# kids_recreation_and_party| retail-gift_shop    | No
# japanese_restaurant | No predicted category| No
# sports_wear         | travel-trains       | No
# bar                 | arts_and_entertainment-theaters_and_performance_venues| No
#
# Number of matching categories: 5
# Total categories compared: 242
# Accuracy: 2.07%
#
# Warning: Original categories list had 251 entries, while predicted categories list had 242 entries. Comparison was done for the first 242 entries.

# %%
import google.generativeai as genai
genai.configure(api_key=api_key)
model = genai.GenerativeModel("gemini-2.0-flash")
comparison_context = "Now you are category comparision agent, I will be providing you with a category that a software predicted for a POI and the actual category of the POI."+\
        "Now I want you to compare each POI's predicted and actual category and let me know if they are similar or not. For example active_life and sports_and_recreation_venue are similar."+\
        f"These are the categories that the software predicted: {predicted_categories_string}"+\
        f"These are the actual categories of the POIs: {primary_categories_string}"+\
        "if they are similar then just say 'yes' otherwise say 'no'. Do not provide any other information or explanation, just the answer. Do not provide any other information or explanation, just the answer which is a yes or a no."+\
        "Again I don't want you to provide the POI names or any other information, just the answer which is a yes or a no. Do not provide any other information or explanation, just the answer which is a yes or a no."

# %%
# Generate content using the model
Comparision = model.generate_content(comparison_context)
print(Comparision.text)
# Calculate and print the percentage of "yes" answers
if 'Comparision' in locals() and hasattr(Comparision, 'text') and Comparision.text:
    answers = Comparision.text.strip().split('\n')
    answers = [ans.strip().lower() for ans in answers if ans.strip()] # Clean and normalize answers
    
    total_answers = len(answers)
    yes_answers = answers.count('yes')
    
    if total_answers > 0:
        yes_percentage = (yes_answers / total_answers) * 100
        print(f"\nTotal 'yes' answers: {yes_answers}")
        print(f"Total answers from LLM: {total_answers}")
        print(f"Percentage of 'yes' answers: {yes_percentage:.2f}%")
    else:
        print("\nNo answers found in LLM Comparision output to calculate statistics.")
else:
    print("\nLLM Comparision output 'Comparision.text' not found or is empty.")
# Out:
# yes
# no
# yes
# no
# no
# yes
# no
# no
# no
# yes
# no
# no
# yes
# yes
# yes
# no
# no
# no
# yes
# no
# yes
# yes
# yes
# yes
# no
# no
# no
# yes
# yes
# no
# no
# yes
# yes
# no
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# no
# yes
# yes
# yes
# yes
# no
# yes
# no
# no
# yes
# no
# yes
# no
# no
# yes
# yes
# no
# no
# no
# yes
# yes
# yes
# no
# yes
# yes
# no
# yes
# no
# no
# no
# no
# yes
# no
# no
# no
# yes
# no
# yes
# yes
# yes
# yes
# yes
# yes
# no
# yes
# yes
# yes
# yes
# yes
# no
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# no
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# no
# yes
# yes
#
#
# Total 'yes' answers: 97
# Total answers from LLM: 139
# Percentage of 'yes' answers: 69.78%
